# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.layers import GlobalAveragePooling2D,Dropout,BatchNormalization
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
from sklearn.metrics import accuracy_score
from scipy.optimize import minimize

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.2)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses):
    modelInput = tf.keras.applications.MobileNetV3Small(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def initiateModel1(noOfClasses):
    modelInput = tf.keras.applications.MobileNetV3Small(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = GlobalAveragePooling2D()(modelInput.output)
    #x = Dropout(0.2)(x)
    #x = Dense(128, activation='relu')(x)
    #x = BatchNormalization()(x)
    prediction = Dense(noOfClasses, activation='softmax')(x)
    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc'),
    ]
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=METRICS)
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'MobileNet.keras', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=gEpochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[7]*100
    TP = evl[1]
    FP = evl[2]
    FN = evl[4]
    TN = evl[3]
    prec = evl[5]
    rec = evl[6]
    F1 = 100 * ((2 * prec * rec) / (prec + rec))
    auc = evl[8]
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    msg+=f'\nTrue Positives = {TP}. True Negatives = {TN}'
    msg+=f'\nFalse Positives = {FP}. False Negatives = {FN}'
    msg+=f'\nPrecision = {prec}'
    msg+=f'\nRecall = {rec}'
    msg+=f'\nF1 Score = {F1}'
    msg+=f'\nROC AUC = {auc}'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - MobileNetV3.keras")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")
    def objective_function(hyperparameters):
        lr,batch = hyperparameters
        accuracy = accuracy_score(y_true,y_pred)
        return -accuracy
    
    accuracy = accuracy_score(y_true, y_pred)
    search_space = [(1e-4, 1e-2), (32, 256)]
    result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')
    best_hyperparameters = result.x
    print("Best Hyperparameters (learning rate, batch size):", best_hyperparameters)

# %%
mpath = r'/kaggle/input/multi-cancer/Multi Cancer'
classPaths = os.listdir(mpath)
IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 10
batchSize = 256
lr = 0.001

for i in classPaths:
    print(i)
# Out:
# Cervical Cancer
# Lung and Colon Cancer
# Oral Cancer
# ALL
# Kidney Cancer
# Breast Cancer
# Lymphoma
# Brain Cancer

# %%
className = 'Cervical Cancer '
cpath = os.path.join(mpath, 'Cervical Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 20000 images belonging to 5 classes.
#
# For Val :  Found 5000 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi']
# Image Shape :  (32, 256, 256, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add (TFOp  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  Lambda)
#
#  re_lu (ReLU)                (None, 112, 112, 16)         0         ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 112, 112, 16)         0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_1[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  OpLambda)                                                          /Conv_1[0][0]']
#
#  re_lu_2 (ReLU)              (None, 1, 1, 16)             0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 16)             0         ['re_lu_2[0][0]']
#  mbda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_1[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_3 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_3[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_4 (ReLU)              (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_4[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_5 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_6 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_6[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_2 (TF  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_7 (ReLU)              (None, 28, 28, 96)           0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  tf.math.multiply_2 (TFOpLa  (None, 28, 28, 96)           0         ['re_lu_7[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_3 (TF  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_8 (ReLU)              (None, 14, 14, 96)           0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  tf.math.multiply_3 (TFOpLa  (None, 14, 14, 96)           0         ['re_lu_8[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_3[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_2[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_9 (ReLU)              (None, 1, 1, 96)             0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  tf.math.multiply_4 (TFOpLa  (None, 1, 1, 96)             0         ['re_lu_9[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_2[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_5 (TF  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_10 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_10[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_6 (TF  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_11 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  tf.math.multiply_6 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_11[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_4[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_12 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  tf.math.multiply_7 (TFOpLa  (None, 1, 1, 240)            0         ['re_lu_12[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_4[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_8 (TF  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_13 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  tf.math.multiply_8 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_13[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_9 (TF  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_14 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  tf.math.multiply_9 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_14[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_6[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_15 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.multiply_10 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_15[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_6[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_11 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  tf.math.multiply_11 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_16[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_12 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  tf.math.multiply_12 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_17[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_8[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_18 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.multiply_13 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_18[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_8[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_14 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  tf.math.multiply_14 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_19[0][0]']
#  ambda)
#
#  multiply_9 (Multiply)       (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_15 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  tf.math.multiply_15 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_20[0][0]']
#  ambda)
#
#  multiply_10 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
# ...
#
#  tf.__operators__.add_24 (T  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_29 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  tf.math.multiply_24 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_29[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_25 (T  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_30 (ReLU)             (None, 1, 1, 576)            0         ['tf.__operators__.add_25[0][0
#                                                                     ]']
#
#  tf.math.multiply_25 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_30[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_25[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_26 (T  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_31 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_26[0][0
#                                                                     ]']
#
#  tf.math.multiply_26 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_31[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_26[0][0]']
#
#  global_average_pooling2d (  (None, 576)                  0         ['multiply_17[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                    2885      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 942005 (3.59 MB)
# Trainable params: 2885 (11.27 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
#   1/625 [..............................] - ETA: 1:19:08 - loss: 2.1457 - tp: 1.0000 - fp: 19.0000 - tn: 109.0000 - fn: 31.0000 - precision: 0.0500 - recall: 0.0312 - accuracy: 0.0938 - auc: 0.5009
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711792400.716449     106 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 [==============================] - ETA: 0s - loss: 0.4924 - tp: 15140.0000 - fp: 1480.0000 - tn: 78520.0000 - fn: 4860.0000 - precision: 0.9110 - recall: 0.7570 - accuracy: 0.8368 - auc: 0.9741
# Epoch 1: val_loss improved from inf to 0.27576, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 232s 360ms/step - loss: 0.4924 - tp: 15140.0000 - fp: 1480.0000 - tn: 78520.0000 - fn: 4860.0000 - precision: 0.9110 - recall: 0.7570 - accuracy: 0.8368 - auc: 0.9741 - val_loss: 0.2758 - val_tp: 4437.0000 - val_fp: 258.0000 - val_tn: 19742.0000 - val_fn: 563.0000 - val_precision: 0.9450 - val_recall: 0.8874 - val_accuracy: 0.9166 - val_auc: 0.9930 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - ETA: 0s - loss: 0.2356 - tp: 18070.0000 - fp: 1018.0000 - tn: 78982.0000 - fn: 1930.0000 - precision: 0.9467 - recall: 0.9035 - accuracy: 0.9269 - auc: 0.9945
# Epoch 2: val_loss improved from 0.27576 to 0.18892, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2356 - tp: 18070.0000 - fp: 1018.0000 - tn: 78982.0000 - fn: 1930.0000 - precision: 0.9467 - recall: 0.9035 - accuracy: 0.9269 - auc: 0.9945 - val_loss: 0.1889 - val_tp: 4622.0000 - val_fp: 189.0000 - val_tn: 19811.0000 - val_fn: 378.0000 - val_precision: 0.9607 - val_recall: 0.9244 - val_accuracy: 0.9450 - val_auc: 0.9971 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - ETA: 0s - loss: 0.1720 - tp: 18681.0000 - fp: 757.0000 - tn: 79243.0000 - fn: 1319.0000 - precision: 0.9611 - recall: 0.9341 - accuracy: 0.9489 - auc: 0.9973
# Epoch 3: val_loss improved from 0.18892 to 0.15113, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 79s 126ms/step - loss: 0.1720 - tp: 18681.0000 - fp: 757.0000 - tn: 79243.0000 - fn: 1319.0000 - precision: 0.9611 - recall: 0.9341 - accuracy: 0.9489 - auc: 0.9973 - val_loss: 0.1511 - val_tp: 4719.0000 - val_fp: 147.0000 - val_tn: 19853.0000 - val_fn: 281.0000 - val_precision: 0.9698 - val_recall: 0.9438 - val_accuracy: 0.9588 - val_auc: 0.9981 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - ETA: 0s - loss: 0.1383 - tp: 18986.0000 - fp: 601.0000 - tn: 79399.0000 - fn: 1014.0000 - precision: 0.9693 - recall: 0.9493 - accuracy: 0.9612 - auc: 0.9984
# Epoch 4: val_loss improved from 0.15113 to 0.12919, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 79s 126ms/step - loss: 0.1383 - tp: 18986.0000 - fp: 601.0000 - tn: 79399.0000 - fn: 1014.0000 - precision: 0.9693 - recall: 0.9493 - accuracy: 0.9612 - auc: 0.9984 - val_loss: 0.1292 - val_tp: 4746.0000 - val_fp: 151.0000 - val_tn: 19849.0000 - val_fn: 254.0000 - val_precision: 0.9692 - val_recall: 0.9492 - val_accuracy: 0.9618 - val_auc: 0.9986 - lr: 0.0010
# Epoch 5/10
# 625/625 [==============================] - ETA: 0s - loss: 0.1157 - tp: 19192.0000 - fp: 512.0000 - tn: 79488.0000 - fn: 808.0000 - precision: 0.9740 - recall: 0.9596 - accuracy: 0.9677 - auc: 0.9989
# Epoch 5: val_loss improved from 0.12919 to 0.10873, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 80s 127ms/step - loss: 0.1157 - tp: 19192.0000 - fp: 512.0000 - tn: 79488.0000 - fn: 808.0000 - precision: 0.9740 - recall: 0.9596 - accuracy: 0.9677 - auc: 0.9989 - val_loss: 0.1087 - val_tp: 4823.0000 - val_fp: 104.0000 - val_tn: 19896.0000 - val_fn: 177.0000 - val_precision: 0.9789 - val_recall: 0.9646 - val_accuracy: 0.9718 - val_auc: 0.9991 - lr: 0.0010
# Epoch 6/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0992 - tp: 19352.0000 - fp: 420.0000 - tn: 79580.0000 - fn: 648.0000 - precision: 0.9788 - recall: 0.9676 - accuracy: 0.9743 - auc: 0.9993
# Epoch 6: val_loss improved from 0.10873 to 0.09787, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0992 - tp: 19352.0000 - fp: 420.0000 - tn: 79580.0000 - fn: 648.0000 - precision: 0.9788 - recall: 0.9676 - accuracy: 0.9743 - auc: 0.9993 - val_loss: 0.0979 - val_tp: 4842.0000 - val_fp: 101.0000 - val_tn: 19899.0000 - val_fn: 158.0000 - val_precision: 0.9796 - val_recall: 0.9684 - val_accuracy: 0.9736 - val_auc: 0.9993 - lr: 0.0010
# Epoch 7/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0873 - tp: 19442.0000 - fp: 388.0000 - tn: 79612.0000 - fn: 558.0000 - precision: 0.9804 - recall: 0.9721 - accuracy: 0.9768 - auc: 0.9994
# Epoch 7: val_loss improved from 0.09787 to 0.08630, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0873 - tp: 19442.0000 - fp: 388.0000 - tn: 79612.0000 - fn: 558.0000 - precision: 0.9804 - recall: 0.9721 - accuracy: 0.9768 - auc: 0.9994 - val_loss: 0.0863 - val_tp: 4866.0000 - val_fp: 92.0000 - val_tn: 19908.0000 - val_fn: 134.0000 - val_precision: 0.9814 - val_recall: 0.9732 - val_accuracy: 0.9768 - val_auc: 0.9995 - lr: 0.0010
# Epoch 8/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0770 - tp: 19521.0000 - fp: 323.0000 - tn: 79677.0000 - fn: 479.0000 - precision: 0.9837 - recall: 0.9761 - accuracy: 0.9806 - auc: 0.9996
# Epoch 8: val_loss improved from 0.08630 to 0.08045, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 81s 129ms/step - loss: 0.0770 - tp: 19521.0000 - fp: 323.0000 - tn: 79677.0000 - fn: 479.0000 - precision: 0.9837 - recall: 0.9761 - accuracy: 0.9806 - auc: 0.9996 - val_loss: 0.0804 - val_tp: 4868.0000 - val_fp: 86.0000 - val_tn: 19914.0000 - val_fn: 132.0000 - val_precision: 0.9826 - val_recall: 0.9736 - val_accuracy: 0.9786 - val_auc: 0.9995 - lr: 0.0010
# Epoch 9/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0702 - tp: 19562.0000 - fp: 309.0000 - tn: 79691.0000 - fn: 438.0000 - precision: 0.9844 - recall: 0.9781 - accuracy: 0.9816 - auc: 0.9997
# Epoch 9: val_loss improved from 0.08045 to 0.07737, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 80s 129ms/step - loss: 0.0702 - tp: 19562.0000 - fp: 309.0000 - tn: 79691.0000 - fn: 438.0000 - precision: 0.9844 - recall: 0.9781 - accuracy: 0.9816 - auc: 0.9997 - val_loss: 0.0774 - val_tp: 4866.0000 - val_fp: 88.0000 - val_tn: 19912.0000 - val_fn: 134.0000 - val_precision: 0.9822 - val_recall: 0.9732 - val_accuracy: 0.9776 - val_auc: 0.9995 - lr: 0.0010
# Epoch 10/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0639 - tp: 19633.0000 - fp: 282.0000 - tn: 79718.0000 - fn: 367.0000 - precision: 0.9858 - recall: 0.9816 - accuracy: 0.9836 - auc: 0.9997
# Epoch 10: val_loss improved from 0.07737 to 0.07015, saving model to Cervical Cancer MobileNet.keras
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0639 - tp: 19633.0000 - fp: 282.0000 - tn: 79718.0000 - fn: 367.0000 - precision: 0.9858 - recall: 0.9816 - accuracy: 0.9836 - auc: 0.9997 - val_loss: 0.0702 - val_tp: 4890.0000 - val_fp: 81.0000 - val_tn: 19919.0000 - val_fn: 110.0000 - val_precision: 0.9837 - val_recall: 0.9780 - val_accuracy: 0.9812 - val_auc: 0.9996 - lr: 0.0010
# 157/157 [==============================] - 16s 103ms/step - loss: 0.0702 - tp: 4890.0000 - fp: 81.0000 - tn: 19919.0000 - fn: 110.0000 - precision: 0.9837 - recall: 0.9780 - accuracy: 0.9812 - auc: 0.9996
# Accuracy on the Test Set = 98.12 %
# True Positives = 4890.0. True Negatives = 19919.0
# False Positives = 81.0. False Negatives = 110.0
# Precision = 0.9837055206298828
# Recall = 0.9779999852180481
# F1 Score = 98.08444557727776
# ROC AUC = 0.9995909333229065
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 157/157 [==============================] - 17s 100ms/step
# Predicted :  [0 0 0 ... 4 4 4]
# Best Hyperparameters (learning rate, batch size): [9.95285188e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Lung And Colon Cancer '
cpath = os.path.join(mpath, 'Lung and Colon Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 20000 images belonging to 5 classes.
#
# For Val :  Found 5000 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)          0         ['input_2[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_27 (T  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_32 (ReLU)             (None, 112, 112, 16)         0         ['tf.__operators__.add_27[0][0
#                                                                     ]']
#
#  tf.math.multiply_27 (TFOpL  (None, 112, 112, 16)         0         ['re_lu_32[0][0]']
#  ambda)
#
#  multiply_18 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_27[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_18[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_33 (ReLU)             (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_33[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_28 (T  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  FOpLambda)                                                         /Conv_1[0][0]']
#
#  re_lu_34 (ReLU)             (None, 1, 1, 16)             0         ['tf.__operators__.add_28[0][0
#                                                                     ]']
#
#  tf.math.multiply_28 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_34[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_33[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_28[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_35 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_35[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_36 (ReLU)             (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_36[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_37 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_37[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_38 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_38[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_29 (T  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_39 (ReLU)             (None, 28, 28, 96)           0         ['tf.__operators__.add_29[0][0
#                                                                     ]']
#
#  tf.math.multiply_29 (TFOpL  (None, 28, 28, 96)           0         ['re_lu_39[0][0]']
#  ambda)
#
#  multiply_19 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_29[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_19[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_30 (T  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_40 (ReLU)             (None, 14, 14, 96)           0         ['tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  tf.math.multiply_30 (TFOpL  (None, 14, 14, 96)           0         ['re_lu_40[0][0]']
#  ambda)
#
#  multiply_20 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_30[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_20[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_41 (ReLU)             (None, 1, 1, 96)             0         ['tf.__operators__.add_31[0][0
#                                                                     ]']
#
#  tf.math.multiply_31 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_41[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_20[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_31[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_32 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_42 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_32[0][0
#                                                                     ]']
#
#  tf.math.multiply_32 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_42[0][0]']
#  ambda)
#
#  multiply_21 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_32[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_21[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_33 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_43 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.math.multiply_33 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_43[0][0]']
#  ambda)
#
#  multiply_22 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_33[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_22[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_34 (T  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_44 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_34[0][0
#                                                                     ]']
#
#  tf.math.multiply_34 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_44[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_22[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_34[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_35 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_45 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.math.multiply_35 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_45[0][0]']
#  ambda)
#
#  multiply_23 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_35[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_23[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_36 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_46 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_36[0][0
#                                                                     ]']
#
#  tf.math.multiply_36 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_46[0][0]']
#  ambda)
#
#  multiply_24 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_36[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_24[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_37 (T  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_47 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.math.multiply_37 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_47[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_24[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_37[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_38 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_48 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  tf.math.multiply_38 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_48[0][0]']
#  ambda)
#
#  multiply_25 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_38[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_25[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_39 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_49 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  tf.math.multiply_39 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_49[0][0]']
#  ambda)
#
#  multiply_26 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_39[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_26[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_40 (T  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_50 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_40[0][0
#                                                                     ]']
#
#  tf.math.multiply_40 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_50[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_26[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_40[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_41 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_51 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  tf.math.multiply_41 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_51[0][0]']
#  ambda)
#
#  multiply_27 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_41[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_27[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_42 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_52 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_42[0][0
#                                                                     ]']
#
#  tf.math.multiply_42 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_52[0][0]']
#  ambda)
#
#  multiply_28 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_42[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_28[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
# ...
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_51 (T  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_61 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_51[0][0
#                                                                     ]']
#
#  tf.math.multiply_51 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_61[0][0]']
#  ambda)
#
#  multiply_34 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_51[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_34[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_52 (T  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_62 (ReLU)             (None, 1, 1, 576)            0         ['tf.__operators__.add_52[0][0
#                                                                     ]']
#
#  tf.math.multiply_52 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_62[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_34[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_52[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_53 (T  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_63 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_53[0][0
#                                                                     ]']
#
#  tf.math.multiply_53 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_63[0][0]']
#  ambda)
#
#  multiply_35 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_53[0][0]']
#
#  global_average_pooling2d_1  (None, 576)                  0         ['multiply_35[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 5)                    2885      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 942005 (3.59 MB)
# Trainable params: 2885 (11.27 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 625/625 [==============================] - ETA: 0s - loss: 0.2671 - tp: 17580.0000 - fp: 846.0000 - tn: 79154.0000 - fn: 2420.0000 - precision: 0.9541 - recall: 0.8790 - accuracy: 0.9186 - auc: 0.9934
# Epoch 1: val_loss improved from inf to 0.10718, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 248s 390ms/step - loss: 0.2671 - tp: 17580.0000 - fp: 846.0000 - tn: 79154.0000 - fn: 2420.0000 - precision: 0.9541 - recall: 0.8790 - accuracy: 0.9186 - auc: 0.9934 - val_loss: 0.1072 - val_tp: 4827.0000 - val_fp: 141.0000 - val_tn: 19859.0000 - val_fn: 173.0000 - val_precision: 0.9716 - val_recall: 0.9654 - val_accuracy: 0.9690 - val_auc: 0.9990 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0889 - tp: 19384.0000 - fp: 507.0000 - tn: 79493.0000 - fn: 616.0000 - precision: 0.9745 - recall: 0.9692 - accuracy: 0.9722 - auc: 0.9992
# Epoch 2: val_loss improved from 0.10718 to 0.07550, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 81s 130ms/step - loss: 0.0889 - tp: 19384.0000 - fp: 507.0000 - tn: 79493.0000 - fn: 616.0000 - precision: 0.9745 - recall: 0.9692 - accuracy: 0.9722 - auc: 0.9992 - val_loss: 0.0755 - val_tp: 4870.0000 - val_fp: 114.0000 - val_tn: 19886.0000 - val_fn: 130.0000 - val_precision: 0.9771 - val_recall: 0.9740 - val_accuracy: 0.9762 - val_auc: 0.9994 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0663 - tp: 19538.0000 - fp: 411.0000 - tn: 79589.0000 - fn: 462.0000 - precision: 0.9794 - recall: 0.9769 - accuracy: 0.9782 - auc: 0.9995
# Epoch 3: val_loss improved from 0.07550 to 0.06249, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 81s 130ms/step - loss: 0.0663 - tp: 19538.0000 - fp: 411.0000 - tn: 79589.0000 - fn: 462.0000 - precision: 0.9794 - recall: 0.9769 - accuracy: 0.9782 - auc: 0.9995 - val_loss: 0.0625 - val_tp: 4891.0000 - val_fp: 103.0000 - val_tn: 19897.0000 - val_fn: 109.0000 - val_precision: 0.9794 - val_recall: 0.9782 - val_accuracy: 0.9790 - val_auc: 0.9996 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0541 - tp: 19646.0000 - fp: 330.0000 - tn: 79670.0000 - fn: 354.0000 - precision: 0.9835 - recall: 0.9823 - accuracy: 0.9830 - auc: 0.9997
# Epoch 4: val_loss improved from 0.06249 to 0.05399, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 84s 135ms/step - loss: 0.0541 - tp: 19646.0000 - fp: 330.0000 - tn: 79670.0000 - fn: 354.0000 - precision: 0.9835 - recall: 0.9823 - accuracy: 0.9830 - auc: 0.9997 - val_loss: 0.0540 - val_tp: 4907.0000 - val_fp: 87.0000 - val_tn: 19913.0000 - val_fn: 93.0000 - val_precision: 0.9826 - val_recall: 0.9814 - val_accuracy: 0.9820 - val_auc: 0.9997 - lr: 0.0010
# Epoch 5/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0471 - tp: 19668.0000 - fp: 310.0000 - tn: 79690.0000 - fn: 332.0000 - precision: 0.9845 - recall: 0.9834 - accuracy: 0.9838 - auc: 0.9998
# Epoch 5: val_loss improved from 0.05399 to 0.04752, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 85s 136ms/step - loss: 0.0471 - tp: 19668.0000 - fp: 310.0000 - tn: 79690.0000 - fn: 332.0000 - precision: 0.9845 - recall: 0.9834 - accuracy: 0.9838 - auc: 0.9998 - val_loss: 0.0475 - val_tp: 4922.0000 - val_fp: 71.0000 - val_tn: 19929.0000 - val_fn: 78.0000 - val_precision: 0.9858 - val_recall: 0.9844 - val_accuracy: 0.9854 - val_auc: 0.9997 - lr: 0.0010
# Epoch 6/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0406 - tp: 19728.0000 - fp: 255.0000 - tn: 79745.0000 - fn: 272.0000 - precision: 0.9872 - recall: 0.9864 - accuracy: 0.9868 - auc: 0.9998
# Epoch 6: val_loss improved from 0.04752 to 0.04319, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 84s 135ms/step - loss: 0.0406 - tp: 19728.0000 - fp: 255.0000 - tn: 79745.0000 - fn: 272.0000 - precision: 0.9872 - recall: 0.9864 - accuracy: 0.9868 - auc: 0.9998 - val_loss: 0.0432 - val_tp: 4930.0000 - val_fp: 69.0000 - val_tn: 19931.0000 - val_fn: 70.0000 - val_precision: 0.9862 - val_recall: 0.9860 - val_accuracy: 0.9860 - val_auc: 0.9998 - lr: 0.0010
# Epoch 7/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0365 - tp: 19767.0000 - fp: 220.0000 - tn: 79780.0000 - fn: 233.0000 - precision: 0.9890 - recall: 0.9883 - accuracy: 0.9886 - auc: 0.9999
# Epoch 7: val_loss improved from 0.04319 to 0.03900, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 83s 132ms/step - loss: 0.0365 - tp: 19767.0000 - fp: 220.0000 - tn: 79780.0000 - fn: 233.0000 - precision: 0.9890 - recall: 0.9883 - accuracy: 0.9886 - auc: 0.9999 - val_loss: 0.0390 - val_tp: 4934.0000 - val_fp: 66.0000 - val_tn: 19934.0000 - val_fn: 66.0000 - val_precision: 0.9868 - val_recall: 0.9868 - val_accuracy: 0.9868 - val_auc: 0.9998 - lr: 0.0010
# Epoch 8/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0330 - tp: 19792.0000 - fp: 197.0000 - tn: 79803.0000 - fn: 208.0000 - precision: 0.9901 - recall: 0.9896 - accuracy: 0.9899 - auc: 0.9999
# Epoch 8: val_loss improved from 0.03900 to 0.03824, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 83s 133ms/step - loss: 0.0330 - tp: 19792.0000 - fp: 197.0000 - tn: 79803.0000 - fn: 208.0000 - precision: 0.9901 - recall: 0.9896 - accuracy: 0.9899 - auc: 0.9999 - val_loss: 0.0382 - val_tp: 4941.0000 - val_fp: 58.0000 - val_tn: 19942.0000 - val_fn: 59.0000 - val_precision: 0.9884 - val_recall: 0.9882 - val_accuracy: 0.9882 - val_auc: 0.9998 - lr: 0.0010
# Epoch 9/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0300 - tp: 19817.0000 - fp: 180.0000 - tn: 79820.0000 - fn: 183.0000 - precision: 0.9910 - recall: 0.9908 - accuracy: 0.9909 - auc: 0.9999
# Epoch 9: val_loss improved from 0.03824 to 0.03563, saving model to Lung And Colon Cancer MobileNet.keras
# 625/625 [==============================] - 83s 133ms/step - loss: 0.0300 - tp: 19817.0000 - fp: 180.0000 - tn: 79820.0000 - fn: 183.0000 - precision: 0.9910 - recall: 0.9908 - accuracy: 0.9909 - auc: 0.9999 - val_loss: 0.0356 - val_tp: 4937.0000 - val_fp: 62.0000 - val_tn: 19938.0000 - val_fn: 63.0000 - val_precision: 0.9876 - val_recall: 0.9874 - val_accuracy: 0.9874 - val_auc: 0.9998 - lr: 0.0010
# Epoch 10/10
# 625/625 [==============================] - ETA: 0s - loss: 0.0279 - tp: 19825.0000 - fp: 169.0000 - tn: 79831.0000 - fn: 175.0000 - precision: 0.9915 - recall: 0.9912 - accuracy: 0.9915 - auc: 0.9999
# Epoch 10: val_loss did not improve from 0.03563
# 625/625 [==============================] - 84s 135ms/step - loss: 0.0279 - tp: 19825.0000 - fp: 169.0000 - tn: 79831.0000 - fn: 175.0000 - precision: 0.9915 - recall: 0.9912 - accuracy: 0.9915 - auc: 0.9999 - val_loss: 0.0455 - val_tp: 4910.0000 - val_fp: 89.0000 - val_tn: 19911.0000 - val_fn: 90.0000 - val_precision: 0.9822 - val_recall: 0.9820 - val_accuracy: 0.9822 - val_auc: 0.9997 - lr: 0.0010
# 157/157 [==============================] - 17s 105ms/step - loss: 0.0455 - tp: 4910.0000 - fp: 89.0000 - tn: 19911.0000 - fn: 90.0000 - precision: 0.9822 - recall: 0.9820 - accuracy: 0.9822 - auc: 0.9997
# Accuracy on the Test Set = 98.22 %
# True Positives = 4910.0. True Negatives = 19911.0
# False Positives = 89.0. False Negatives = 90.0
# Precision = 0.9821964502334595
# Recall = 0.9819999933242798
# F1 Score = 98.20982119541605
# ROC AUC = 0.9997036457061768
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 157/157 [==============================] - 18s 108ms/step
# Predicted :  [0 0 0 ... 4 4 4]
# Best Hyperparameters (learning rate, batch size): [9.95284101e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Oral Cancer '
cpath = os.path.join(mpath, 'Oral Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10002 files belonging to 2 classes.
#
# For Training :  Found 8002 images belonging to 2 classes.
#
# For Val :  Found 2000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['oral_normal', 'oral_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 224, 224, 3)          0         ['input_3[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_2[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_54 (T  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_64 (ReLU)             (None, 112, 112, 16)         0         ['tf.__operators__.add_54[0][0
#                                                                     ]']
#
#  tf.math.multiply_54 (TFOpL  (None, 112, 112, 16)         0         ['re_lu_64[0][0]']
#  ambda)
#
#  multiply_36 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_54[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_36[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_65 (ReLU)             (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_65[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_55 (T  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  FOpLambda)                                                         /Conv_1[0][0]']
#
#  re_lu_66 (ReLU)             (None, 1, 1, 16)             0         ['tf.__operators__.add_55[0][0
#                                                                     ]']
#
#  tf.math.multiply_55 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_66[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_65[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_55[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_67 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_67[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_68 (ReLU)             (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_68[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_69 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_69[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_70 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_70[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_56 (T  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_71 (ReLU)             (None, 28, 28, 96)           0         ['tf.__operators__.add_56[0][0
#                                                                     ]']
#
#  tf.math.multiply_56 (TFOpL  (None, 28, 28, 96)           0         ['re_lu_71[0][0]']
#  ambda)
#
#  multiply_37 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_56[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_37[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_57 (T  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_72 (ReLU)             (None, 14, 14, 96)           0         ['tf.__operators__.add_57[0][0
#                                                                     ]']
#
#  tf.math.multiply_57 (TFOpL  (None, 14, 14, 96)           0         ['re_lu_72[0][0]']
#  ambda)
#
#  multiply_38 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_38[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_58 (T  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_73 (ReLU)             (None, 1, 1, 96)             0         ['tf.__operators__.add_58[0][0
#                                                                     ]']
#
#  tf.math.multiply_58 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_73[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_38[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_58[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_59 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_74 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_59[0][0
#                                                                     ]']
#
#  tf.math.multiply_59 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_74[0][0]']
#  ambda)
#
#  multiply_39 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_59[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_39[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_60 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_75 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_60[0][0
#                                                                     ]']
#
#  tf.math.multiply_60 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_75[0][0]']
#  ambda)
#
#  multiply_40 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_60[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_40[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_61 (T  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_76 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_61[0][0
#                                                                     ]']
#
#  tf.math.multiply_61 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_76[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_40[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_61[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_62 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_77 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_62[0][0
#                                                                     ]']
#
#  tf.math.multiply_62 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_77[0][0]']
#  ambda)
#
#  multiply_41 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_62[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_41[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_63 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_78 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_63[0][0
#                                                                     ]']
#
#  tf.math.multiply_63 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_78[0][0]']
#  ambda)
#
#  multiply_42 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_63[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_42[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_64 (T  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_79 (ReLU)             (None, 1, 1, 240)            0         ['tf.__operators__.add_64[0][0
#                                                                     ]']
#
#  tf.math.multiply_64 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_79[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_42[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_64[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_65 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_80 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_65[0][0
#                                                                     ]']
#
#  tf.math.multiply_65 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_80[0][0]']
#  ambda)
#
#  multiply_43 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_65[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_43[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_66 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_81 (ReLU)             (None, 14, 14, 120)          0         ['tf.__operators__.add_66[0][0
#                                                                     ]']
#
#  tf.math.multiply_66 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_81[0][0]']
#  ambda)
#
#  multiply_44 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_66[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_44[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_67 (T  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_82 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_67[0][0
#                                                                     ]']
#
#  tf.math.multiply_67 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_82[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_44[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_67[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_68 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_83 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_68[0][0
#                                                                     ]']
#
#  tf.math.multiply_68 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_83[0][0]']
#  ambda)
#
#  multiply_45 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_68[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_45[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_69 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_84 (ReLU)             (None, 14, 14, 144)          0         ['tf.__operators__.add_69[0][0
#                                                                     ]']
#
#  tf.math.multiply_69 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_84[0][0]']
#  ambda)
#
#  multiply_46 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_69[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_46[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
# ...
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_78 (T  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_93 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_78[0][0
#                                                                     ]']
#
#  tf.math.multiply_78 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_93[0][0]']
#  ambda)
#
#  multiply_52 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_78[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_52[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_79 (T  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_94 (ReLU)             (None, 1, 1, 576)            0         ['tf.__operators__.add_79[0][0
#                                                                     ]']
#
#  tf.math.multiply_79 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_94[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_52[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_79[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_80 (T  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_95 (ReLU)             (None, 7, 7, 576)            0         ['tf.__operators__.add_80[0][0
#                                                                     ]']
#
#  tf.math.multiply_80 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_95[0][0]']
#  ambda)
#
#  multiply_53 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_80[0][0]']
#
#  global_average_pooling2d_2  (None, 576)                  0         ['multiply_53[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 2)                    1154      ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 940274 (3.59 MB)
# Trainable params: 1154 (4.51 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 251/251 [==============================] - ETA: 0s - loss: 0.5293 - tp: 5821.0000 - fp: 2181.0000 - tn: 5821.0000 - fn: 2181.0000 - precision: 0.7274 - recall: 0.7274 - accuracy: 0.7274 - auc: 0.8093
# Epoch 1: val_loss improved from inf to 0.45895, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 100s 384ms/step - loss: 0.5293 - tp: 5821.0000 - fp: 2181.0000 - tn: 5821.0000 - fn: 2181.0000 - precision: 0.7274 - recall: 0.7274 - accuracy: 0.7274 - auc: 0.8093 - val_loss: 0.4590 - val_tp: 1564.0000 - val_fp: 436.0000 - val_tn: 1564.0000 - val_fn: 436.0000 - val_precision: 0.7820 - val_recall: 0.7820 - val_accuracy: 0.7820 - val_auc: 0.8657 - lr: 0.0010
# Epoch 2/10
# 251/251 [==============================] - ETA: 0s - loss: 0.4135 - tp: 6493.0000 - fp: 1509.0000 - tn: 6493.0000 - fn: 1509.0000 - precision: 0.8114 - recall: 0.8114 - accuracy: 0.8114 - auc: 0.8949
# Epoch 2: val_loss improved from 0.45895 to 0.41795, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 33s 133ms/step - loss: 0.4135 - tp: 6493.0000 - fp: 1509.0000 - tn: 6493.0000 - fn: 1509.0000 - precision: 0.8114 - recall: 0.8114 - accuracy: 0.8114 - auc: 0.8949 - val_loss: 0.4179 - val_tp: 1591.0000 - val_fp: 409.0000 - val_tn: 1591.0000 - val_fn: 409.0000 - val_precision: 0.7955 - val_recall: 0.7955 - val_accuracy: 0.7955 - val_auc: 0.8902 - lr: 0.0010
# Epoch 3/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3774 - tp: 6661.0000 - fp: 1341.0000 - tn: 6661.0000 - fn: 1341.0000 - precision: 0.8324 - recall: 0.8324 - accuracy: 0.8324 - auc: 0.9146
# Epoch 3: val_loss improved from 0.41795 to 0.39221, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 33s 131ms/step - loss: 0.3774 - tp: 6661.0000 - fp: 1341.0000 - tn: 6661.0000 - fn: 1341.0000 - precision: 0.8324 - recall: 0.8324 - accuracy: 0.8324 - auc: 0.9146 - val_loss: 0.3922 - val_tp: 1632.0000 - val_fp: 368.0000 - val_tn: 1632.0000 - val_fn: 368.0000 - val_precision: 0.8160 - val_recall: 0.8160 - val_accuracy: 0.8160 - val_auc: 0.9044 - lr: 0.0010
# Epoch 4/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3545 - tp: 6770.0000 - fp: 1232.0000 - tn: 6770.0000 - fn: 1232.0000 - precision: 0.8460 - recall: 0.8460 - accuracy: 0.8460 - auc: 0.9252
# Epoch 4: val_loss improved from 0.39221 to 0.37235, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 34s 137ms/step - loss: 0.3545 - tp: 6770.0000 - fp: 1232.0000 - tn: 6770.0000 - fn: 1232.0000 - precision: 0.8460 - recall: 0.8460 - accuracy: 0.8460 - auc: 0.9252 - val_loss: 0.3724 - val_tp: 1665.0000 - val_fp: 335.0000 - val_tn: 1665.0000 - val_fn: 335.0000 - val_precision: 0.8325 - val_recall: 0.8325 - val_accuracy: 0.8325 - val_auc: 0.9152 - lr: 0.0010
# Epoch 5/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3398 - tp: 6844.0000 - fp: 1158.0000 - tn: 6844.0000 - fn: 1158.0000 - precision: 0.8553 - recall: 0.8553 - accuracy: 0.8553 - auc: 0.9315
# Epoch 5: val_loss improved from 0.37235 to 0.36049, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 33s 130ms/step - loss: 0.3398 - tp: 6844.0000 - fp: 1158.0000 - tn: 6844.0000 - fn: 1158.0000 - precision: 0.8553 - recall: 0.8553 - accuracy: 0.8553 - auc: 0.9315 - val_loss: 0.3605 - val_tp: 1683.0000 - val_fp: 317.0000 - val_tn: 1683.0000 - val_fn: 317.0000 - val_precision: 0.8415 - val_recall: 0.8415 - val_accuracy: 0.8415 - val_auc: 0.9206 - lr: 0.0010
# Epoch 6/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3258 - tp: 6911.0000 - fp: 1091.0000 - tn: 6911.0000 - fn: 1091.0000 - precision: 0.8637 - recall: 0.8637 - accuracy: 0.8637 - auc: 0.9377
# Epoch 6: val_loss improved from 0.36049 to 0.35617, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 35s 138ms/step - loss: 0.3258 - tp: 6911.0000 - fp: 1091.0000 - tn: 6911.0000 - fn: 1091.0000 - precision: 0.8637 - recall: 0.8637 - accuracy: 0.8637 - auc: 0.9377 - val_loss: 0.3562 - val_tp: 1678.0000 - val_fp: 322.0000 - val_tn: 1678.0000 - val_fn: 322.0000 - val_precision: 0.8390 - val_recall: 0.8390 - val_accuracy: 0.8390 - val_auc: 0.9218 - lr: 0.0010
# Epoch 7/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3182 - tp: 6933.0000 - fp: 1069.0000 - tn: 6933.0000 - fn: 1069.0000 - precision: 0.8664 - recall: 0.8664 - accuracy: 0.8664 - auc: 0.9401
# Epoch 7: val_loss improved from 0.35617 to 0.34994, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 33s 132ms/step - loss: 0.3182 - tp: 6933.0000 - fp: 1069.0000 - tn: 6933.0000 - fn: 1069.0000 - precision: 0.8664 - recall: 0.8664 - accuracy: 0.8664 - auc: 0.9401 - val_loss: 0.3499 - val_tp: 1694.0000 - val_fp: 306.0000 - val_tn: 1694.0000 - val_fn: 306.0000 - val_precision: 0.8470 - val_recall: 0.8470 - val_accuracy: 0.8470 - val_auc: 0.9248 - lr: 0.0010
# Epoch 8/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3078 - tp: 6990.0000 - fp: 1012.0000 - tn: 6990.0000 - fn: 1012.0000 - precision: 0.8735 - recall: 0.8735 - accuracy: 0.8735 - auc: 0.9443
# Epoch 8: val_loss improved from 0.34994 to 0.33941, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 33s 131ms/step - loss: 0.3078 - tp: 6990.0000 - fp: 1012.0000 - tn: 6990.0000 - fn: 1012.0000 - precision: 0.8735 - recall: 0.8735 - accuracy: 0.8735 - auc: 0.9443 - val_loss: 0.3394 - val_tp: 1702.0000 - val_fp: 298.0000 - val_tn: 1702.0000 - val_fn: 298.0000 - val_precision: 0.8510 - val_recall: 0.8510 - val_accuracy: 0.8510 - val_auc: 0.9297 - lr: 0.0010
# Epoch 9/10
# 251/251 [==============================] - ETA: 0s - loss: 0.3030 - tp: 6997.0000 - fp: 1005.0000 - tn: 6997.0000 - fn: 1005.0000 - precision: 0.8744 - recall: 0.8744 - accuracy: 0.8744 - auc: 0.9460
# Epoch 9: val_loss improved from 0.33941 to 0.33505, saving model to Oral Cancer MobileNet.keras
# 251/251 [==============================] - 32s 129ms/step - loss: 0.3030 - tp: 6997.0000 - fp: 1005.0000 - tn: 6997.0000 - fn: 1005.0000 - precision: 0.8744 - recall: 0.8744 - accuracy: 0.8744 - auc: 0.9460 - val_loss: 0.3350 - val_tp: 1709.0000 - val_fp: 291.0000 - val_tn: 1709.0000 - val_fn: 291.0000 - val_precision: 0.8545 - val_recall: 0.8545 - val_accuracy: 0.8545 - val_auc: 0.9314 - lr: 0.0010
# Epoch 10/10
# 251/251 [==============================] - ETA: 0s - loss: 0.2978 - tp: 7013.0000 - fp: 989.0000 - tn: 7013.0000 - fn: 989.0000 - precision: 0.8764 - recall: 0.8764 - accuracy: 0.8764 - auc: 0.9477
# Epoch 10: val_loss did not improve from 0.33505
# 251/251 [==============================] - 34s 134ms/step - loss: 0.2978 - tp: 7013.0000 - fp: 989.0000 - tn: 7013.0000 - fn: 989.0000 - precision: 0.8764 - recall: 0.8764 - accuracy: 0.8764 - auc: 0.9477 - val_loss: 0.3374 - val_tp: 1686.0000 - val_fp: 314.0000 - val_tn: 1686.0000 - val_fn: 314.0000 - val_precision: 0.8430 - val_recall: 0.8430 - val_accuracy: 0.8430 - val_auc: 0.9298 - lr: 0.0010
# 63/63 [==============================] - 6s 102ms/step - loss: 0.3374 - tp: 1686.0000 - fp: 314.0000 - tn: 1686.0000 - fn: 314.0000 - precision: 0.8430 - recall: 0.8430 - accuracy: 0.8430 - auc: 0.9298
# Accuracy on the Test Set = 84.30 %
# True Positives = 1686.0. True Negatives = 1686.0
# False Positives = 314.0. False Negatives = 314.0
# Precision = 0.8429999947547913
# Recall = 0.8429999947547913
# F1 Score = 84.29999947547913
# ROC AUC = 0.9298345446586609
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# 63/63 [==============================] - 7s 100ms/step
# Predicted :  [0 0 0 ... 1 1 1]
# Best Hyperparameters (learning rate, batch size): [9.95284038e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'ALL'
cpath = os.path.join(mpath, 'ALL')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 20000 files belonging to 4 classes.
#
# For Training :  Found 16000 images belonging to 4 classes.
#
# For Val :  Found 4000 images belonging to 4 classes.
#
# No of Classes :  4
# Classes :  ['all_benign', 'all_early', 'all_pre', 'all_pro']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_3 (Rescaling)     (None, 224, 224, 3)          0         ['input_4[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_3[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_81 (T  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_96 (ReLU)             (None, 112, 112, 16)         0         ['tf.__operators__.add_81[0][0
#                                                                     ]']
#
#  tf.math.multiply_81 (TFOpL  (None, 112, 112, 16)         0         ['re_lu_96[0][0]']
#  ambda)
#
#  multiply_54 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_81[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_54[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_97 (ReLU)             (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_97[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_82 (T  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  FOpLambda)                                                         /Conv_1[0][0]']
#
#  re_lu_98 (ReLU)             (None, 1, 1, 16)             0         ['tf.__operators__.add_82[0][0
#                                                                     ]']
#
#  tf.math.multiply_82 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_98[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_97[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_82[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_99 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_99[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_100 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_100[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_101 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_101[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_102 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_102[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_83 (T  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_103 (ReLU)            (None, 28, 28, 96)           0         ['tf.__operators__.add_83[0][0
#                                                                     ]']
#
#  tf.math.multiply_83 (TFOpL  (None, 28, 28, 96)           0         ['re_lu_103[0][0]']
#  ambda)
#
#  multiply_55 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_83[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_55[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_84 (T  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_104 (ReLU)            (None, 14, 14, 96)           0         ['tf.__operators__.add_84[0][0
#                                                                     ]']
#
#  tf.math.multiply_84 (TFOpL  (None, 14, 14, 96)           0         ['re_lu_104[0][0]']
#  ambda)
#
#  multiply_56 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_84[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_56[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_85 (T  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_105 (ReLU)            (None, 1, 1, 96)             0         ['tf.__operators__.add_85[0][0
#                                                                     ]']
#
#  tf.math.multiply_85 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_105[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_56[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_85[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_86 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_106 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_86[0][0
#                                                                     ]']
#
#  tf.math.multiply_86 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_106[0][0]']
#  ambda)
#
#  multiply_57 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_86[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_57[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_87 (T  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_107 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_87[0][0
#                                                                     ]']
#
#  tf.math.multiply_87 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_107[0][0]']
#  ambda)
#
#  multiply_58 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_87[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_58[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_88 (T  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_108 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_88[0][0
#                                                                     ]']
#
#  tf.math.multiply_88 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_108[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_58[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_88[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_89 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_109 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_89[0][0
#                                                                     ]']
#
#  tf.math.multiply_89 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_109[0][0]']
#  ambda)
#
#  multiply_59 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_89[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_59[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_90 (T  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_110 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_90[0][0
#                                                                     ]']
#
#  tf.math.multiply_90 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_110[0][0]']
#  ambda)
#
#  multiply_60 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_90[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_60[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_91 (T  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_111 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_91[0][0
#                                                                     ]']
#
#  tf.math.multiply_91 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_111[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_60[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_91[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_92 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_112 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_92[0][0
#                                                                     ]']
#
#  tf.math.multiply_92 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_112[0][0]']
#  ambda)
#
#  multiply_61 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_92[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_61[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_93 (T  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_113 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_93[0][0
#                                                                     ]']
#
#  tf.math.multiply_93 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_113[0][0]']
#  ambda)
#
#  multiply_62 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_93[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_62[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_94 (T  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_114 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_94[0][0
#                                                                     ]']
#
#  tf.math.multiply_94 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_114[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_62[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_94[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_95 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_115 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_95[0][0
#                                                                     ]']
#
#  tf.math.multiply_95 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_115[0][0]']
#  ambda)
#
#  multiply_63 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_95[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_63[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_96 (T  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_116 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_96[0][0
#                                                                     ]']
#
#  tf.math.multiply_96 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_116[0][0]']
#  ambda)
#
#  multiply_64 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_96[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_64[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
# ...
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_69[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_105 (  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_125 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_105[0][
#                                                                     0]']
#
#  tf.math.multiply_105 (TFOp  (None, 7, 7, 576)            0         ['re_lu_125[0][0]']
#  Lambda)
#
#  multiply_70 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_105[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_70[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_106 (  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_126 (ReLU)            (None, 1, 1, 576)            0         ['tf.__operators__.add_106[0][
#                                                                     0]']
#
#  tf.math.multiply_106 (TFOp  (None, 1, 1, 576)            0         ['re_lu_126[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_70[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_106[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_107 (  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_127 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_107[0][
#                                                                     0]']
#
#  tf.math.multiply_107 (TFOp  (None, 7, 7, 576)            0         ['re_lu_127[0][0]']
#  Lambda)
#
#  multiply_71 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_107[0][0]']
#
#  global_average_pooling2d_3  (None, 576)                  0         ['multiply_71[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 4)                    2308      ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 941428 (3.59 MB)
# Trainable params: 2308 (9.02 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 500/500 [==============================] - ETA: 0s - loss: 0.3042 - tp: 13742.0000 - fp: 371.0000 - tn: 47629.0000 - fn: 2258.0000 - precision: 0.9737 - recall: 0.8589 - accuracy: 0.9258 - auc: 0.9927
# Epoch 1: val_loss improved from inf to 0.11217, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 194s 379ms/step - loss: 0.3042 - tp: 13742.0000 - fp: 371.0000 - tn: 47629.0000 - fn: 2258.0000 - precision: 0.9737 - recall: 0.8589 - accuracy: 0.9258 - auc: 0.9927 - val_loss: 0.1122 - val_tp: 3894.0000 - val_fp: 55.0000 - val_tn: 11945.0000 - val_fn: 106.0000 - val_precision: 0.9861 - val_recall: 0.9735 - val_accuracy: 0.9795 - val_auc: 0.9991 - lr: 0.0010
# Epoch 2/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0902 - tp: 15618.0000 - fp: 253.0000 - tn: 47747.0000 - fn: 382.0000 - precision: 0.9841 - recall: 0.9761 - accuracy: 0.9802 - auc: 0.9994
# Epoch 2: val_loss improved from 0.11217 to 0.06497, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 61s 123ms/step - loss: 0.0902 - tp: 15618.0000 - fp: 253.0000 - tn: 47747.0000 - fn: 382.0000 - precision: 0.9841 - recall: 0.9761 - accuracy: 0.9802 - auc: 0.9994 - val_loss: 0.0650 - val_tp: 3941.0000 - val_fp: 41.0000 - val_tn: 11959.0000 - val_fn: 59.0000 - val_precision: 0.9897 - val_recall: 0.9852 - val_accuracy: 0.9875 - val_auc: 0.9997 - lr: 0.0010
# Epoch 3/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0595 - tp: 15754.0000 - fp: 185.0000 - tn: 47815.0000 - fn: 246.0000 - precision: 0.9884 - recall: 0.9846 - accuracy: 0.9869 - auc: 0.9997
# Epoch 3: val_loss improved from 0.06497 to 0.04646, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 61s 121ms/step - loss: 0.0595 - tp: 15754.0000 - fp: 185.0000 - tn: 47815.0000 - fn: 246.0000 - precision: 0.9884 - recall: 0.9846 - accuracy: 0.9869 - auc: 0.9997 - val_loss: 0.0465 - val_tp: 3957.0000 - val_fp: 37.0000 - val_tn: 11963.0000 - val_fn: 43.0000 - val_precision: 0.9907 - val_recall: 0.9893 - val_accuracy: 0.9900 - val_auc: 0.9998 - lr: 0.0010
# Epoch 4/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0444 - tp: 15823.0000 - fp: 134.0000 - tn: 47866.0000 - fn: 177.0000 - precision: 0.9916 - recall: 0.9889 - accuracy: 0.9903 - auc: 0.9999
# Epoch 4: val_loss improved from 0.04646 to 0.03594, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 61s 121ms/step - loss: 0.0444 - tp: 15823.0000 - fp: 134.0000 - tn: 47866.0000 - fn: 177.0000 - precision: 0.9916 - recall: 0.9889 - accuracy: 0.9903 - auc: 0.9999 - val_loss: 0.0359 - val_tp: 3967.0000 - val_fp: 28.0000 - val_tn: 11972.0000 - val_fn: 33.0000 - val_precision: 0.9930 - val_recall: 0.9918 - val_accuracy: 0.9923 - val_auc: 0.9999 - lr: 0.0010
# Epoch 5/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0350 - tp: 15868.0000 - fp: 105.0000 - tn: 47895.0000 - fn: 132.0000 - precision: 0.9934 - recall: 0.9918 - accuracy: 0.9929 - auc: 0.9999
# Epoch 5: val_loss improved from 0.03594 to 0.02988, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 60s 119ms/step - loss: 0.0350 - tp: 15868.0000 - fp: 105.0000 - tn: 47895.0000 - fn: 132.0000 - precision: 0.9934 - recall: 0.9918 - accuracy: 0.9929 - auc: 0.9999 - val_loss: 0.0299 - val_tp: 3975.0000 - val_fp: 23.0000 - val_tn: 11977.0000 - val_fn: 25.0000 - val_precision: 0.9942 - val_recall: 0.9937 - val_accuracy: 0.9937 - val_auc: 0.9999 - lr: 0.0010
# Epoch 6/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0289 - tp: 15902.0000 - fp: 78.0000 - tn: 47922.0000 - fn: 98.0000 - precision: 0.9951 - recall: 0.9939 - accuracy: 0.9948 - auc: 1.0000
# Epoch 6: val_loss improved from 0.02988 to 0.02468, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 59s 118ms/step - loss: 0.0289 - tp: 15902.0000 - fp: 78.0000 - tn: 47922.0000 - fn: 98.0000 - precision: 0.9951 - recall: 0.9939 - accuracy: 0.9948 - auc: 1.0000 - val_loss: 0.0247 - val_tp: 3978.0000 - val_fp: 20.0000 - val_tn: 11980.0000 - val_fn: 22.0000 - val_precision: 0.9950 - val_recall: 0.9945 - val_accuracy: 0.9948 - val_auc: 1.0000 - lr: 0.0010
# Epoch 7/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0242 - tp: 15923.0000 - fp: 65.0000 - tn: 47935.0000 - fn: 77.0000 - precision: 0.9959 - recall: 0.9952 - accuracy: 0.9956 - auc: 1.0000
# Epoch 7: val_loss improved from 0.02468 to 0.02109, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 60s 120ms/step - loss: 0.0242 - tp: 15923.0000 - fp: 65.0000 - tn: 47935.0000 - fn: 77.0000 - precision: 0.9959 - recall: 0.9952 - accuracy: 0.9956 - auc: 1.0000 - val_loss: 0.0211 - val_tp: 3981.0000 - val_fp: 16.0000 - val_tn: 11984.0000 - val_fn: 19.0000 - val_precision: 0.9960 - val_recall: 0.9952 - val_accuracy: 0.9955 - val_auc: 1.0000 - lr: 0.0010
# Epoch 8/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0207 - tp: 15938.0000 - fp: 52.0000 - tn: 47948.0000 - fn: 62.0000 - precision: 0.9967 - recall: 0.9961 - accuracy: 0.9966 - auc: 1.0000
# Epoch 8: val_loss improved from 0.02109 to 0.01788, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 60s 119ms/step - loss: 0.0207 - tp: 15938.0000 - fp: 52.0000 - tn: 47948.0000 - fn: 62.0000 - precision: 0.9967 - recall: 0.9961 - accuracy: 0.9966 - auc: 1.0000 - val_loss: 0.0179 - val_tp: 3985.0000 - val_fp: 13.0000 - val_tn: 11987.0000 - val_fn: 15.0000 - val_precision: 0.9967 - val_recall: 0.9962 - val_accuracy: 0.9965 - val_auc: 1.0000 - lr: 0.0010
# Epoch 9/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0178 - tp: 15949.0000 - fp: 43.0000 - tn: 47957.0000 - fn: 51.0000 - precision: 0.9973 - recall: 0.9968 - accuracy: 0.9971 - auc: 1.0000
# Epoch 9: val_loss did not improve from 0.01788
# 500/500 [==============================] - 60s 119ms/step - loss: 0.0178 - tp: 15949.0000 - fp: 43.0000 - tn: 47957.0000 - fn: 51.0000 - precision: 0.9973 - recall: 0.9968 - accuracy: 0.9971 - auc: 1.0000 - val_loss: 0.0206 - val_tp: 3977.0000 - val_fp: 23.0000 - val_tn: 11977.0000 - val_fn: 23.0000 - val_precision: 0.9942 - val_recall: 0.9942 - val_accuracy: 0.9942 - val_auc: 0.9999 - lr: 0.0010
# Epoch 10/10
# 500/500 [==============================] - ETA: 0s - loss: 0.0158 - tp: 15963.0000 - fp: 34.0000 - tn: 47966.0000 - fn: 37.0000 - precision: 0.9979 - recall: 0.9977 - accuracy: 0.9978 - auc: 1.0000
# Epoch 10: val_loss improved from 0.01788 to 0.01432, saving model to ALLMobileNet.keras
# 500/500 [==============================] - 58s 116ms/step - loss: 0.0158 - tp: 15963.0000 - fp: 34.0000 - tn: 47966.0000 - fn: 37.0000 - precision: 0.9979 - recall: 0.9977 - accuracy: 0.9978 - auc: 1.0000 - val_loss: 0.0143 - val_tp: 3987.0000 - val_fp: 11.0000 - val_tn: 11989.0000 - val_fn: 13.0000 - val_precision: 0.9972 - val_recall: 0.9967 - val_accuracy: 0.9967 - val_auc: 1.0000 - lr: 0.0010
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0143 - tp: 3987.0000 - fp: 11.0000 - tn: 11989.0000 - fn: 13.0000 - precision: 0.9972 - recall: 0.9967 - accuracy: 0.9967 - auc: 1.0000
# Accuracy on the Test Set = 99.67 %
# True Positives = 3987.0. True Negatives = 11989.0
# False Positives = 11.0. False Negatives = 13.0
# Precision = 0.997248649597168
# Recall = 0.996749997138977
# F1 Score = 99.69992610174097
# ROC AUC = 0.9999866485595703
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 125/125 [==============================] - 13s 94ms/step
# Predicted :  [0 0 0 ... 3 3 3]
# Best Hyperparameters (learning rate, batch size): [9.95284192e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Kidney Cancer '
cpath = os.path.join(mpath, 'Kidney Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 8000 images belonging to 2 classes.
#
# For Val :  Found 2000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['kidney_normal', 'kidney_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_4 (Rescaling)     (None, 224, 224, 3)          0         ['input_5[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_4[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_108 (  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_128 (ReLU)            (None, 112, 112, 16)         0         ['tf.__operators__.add_108[0][
#                                                                     0]']
#
#  tf.math.multiply_108 (TFOp  (None, 112, 112, 16)         0         ['re_lu_128[0][0]']
#  Lambda)
#
#  multiply_72 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_108[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_72[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_129 (ReLU)            (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_129[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_109 (  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  TFOpLambda)                                                        /Conv_1[0][0]']
#
#  re_lu_130 (ReLU)            (None, 1, 1, 16)             0         ['tf.__operators__.add_109[0][
#                                                                     0]']
#
#  tf.math.multiply_109 (TFOp  (None, 1, 1, 16)             0         ['re_lu_130[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_129[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_109[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_131 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_131[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_132 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_132[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_133 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_133[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_134 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_134[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_110 (  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_135 (ReLU)            (None, 28, 28, 96)           0         ['tf.__operators__.add_110[0][
#                                                                     0]']
#
#  tf.math.multiply_110 (TFOp  (None, 28, 28, 96)           0         ['re_lu_135[0][0]']
#  Lambda)
#
#  multiply_73 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_110[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_73[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_111 (  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_136 (ReLU)            (None, 14, 14, 96)           0         ['tf.__operators__.add_111[0][
#                                                                     0]']
#
#  tf.math.multiply_111 (TFOp  (None, 14, 14, 96)           0         ['re_lu_136[0][0]']
#  Lambda)
#
#  multiply_74 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_111[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_74[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_112 (  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_137 (ReLU)            (None, 1, 1, 96)             0         ['tf.__operators__.add_112[0][
#                                                                     0]']
#
#  tf.math.multiply_112 (TFOp  (None, 1, 1, 96)             0         ['re_lu_137[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_74[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_112[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_113 (  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_138 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_113[0][
#                                                                     0]']
#
#  tf.math.multiply_113 (TFOp  (None, 14, 14, 240)          0         ['re_lu_138[0][0]']
#  Lambda)
#
#  multiply_75 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_113[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_75[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_114 (  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_139 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_114[0][
#                                                                     0]']
#
#  tf.math.multiply_114 (TFOp  (None, 14, 14, 240)          0         ['re_lu_139[0][0]']
#  Lambda)
#
#  multiply_76 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_114[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_76[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_115 (  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_140 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_115[0][
#                                                                     0]']
#
#  tf.math.multiply_115 (TFOp  (None, 1, 1, 240)            0         ['re_lu_140[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_76[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_115[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_116 (  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_141 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_116[0][
#                                                                     0]']
#
#  tf.math.multiply_116 (TFOp  (None, 14, 14, 240)          0         ['re_lu_141[0][0]']
#  Lambda)
#
#  multiply_77 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_116[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_77[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_117 (  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_142 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_117[0][
#                                                                     0]']
#
#  tf.math.multiply_117 (TFOp  (None, 14, 14, 240)          0         ['re_lu_142[0][0]']
#  Lambda)
#
#  multiply_78 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_117[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_78[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_118 (  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_143 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_118[0][
#                                                                     0]']
#
#  tf.math.multiply_118 (TFOp  (None, 1, 1, 240)            0         ['re_lu_143[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_78[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_118[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_119 (  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_144 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_119[0][
#                                                                     0]']
#
#  tf.math.multiply_119 (TFOp  (None, 14, 14, 120)          0         ['re_lu_144[0][0]']
#  Lambda)
#
#  multiply_79 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_119[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_79[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_120 (  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_145 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_120[0][
#                                                                     0]']
#
#  tf.math.multiply_120 (TFOp  (None, 14, 14, 120)          0         ['re_lu_145[0][0]']
#  Lambda)
#
#  multiply_80 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_120[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_80[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_121 (  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_146 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_121[0][
#                                                                     0]']
#
#  tf.math.multiply_121 (TFOp  (None, 1, 1, 120)            0         ['re_lu_146[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_80[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_121[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_122 (  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_147 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_122[0][
#                                                                     0]']
#
#  tf.math.multiply_122 (TFOp  (None, 14, 14, 144)          0         ['re_lu_147[0][0]']
#  Lambda)
#
#  multiply_81 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_122[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_81[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_123 (  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_148 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_123[0][
#                                                                     0]']
#
#  tf.math.multiply_123 (TFOp  (None, 14, 14, 144)          0         ['re_lu_148[0][0]']
#  Lambda)
#
#  multiply_82 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_123[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_82[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
# ...
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_87[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_132 (  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_157 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_132[0][
#                                                                     0]']
#
#  tf.math.multiply_132 (TFOp  (None, 7, 7, 576)            0         ['re_lu_157[0][0]']
#  Lambda)
#
#  multiply_88 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_132[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_88[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_133 (  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_158 (ReLU)            (None, 1, 1, 576)            0         ['tf.__operators__.add_133[0][
#                                                                     0]']
#
#  tf.math.multiply_133 (TFOp  (None, 1, 1, 576)            0         ['re_lu_158[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_88[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_133[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_134 (  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_159 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_134[0][
#                                                                     0]']
#
#  tf.math.multiply_134 (TFOp  (None, 7, 7, 576)            0         ['re_lu_159[0][0]']
#  Lambda)
#
#  multiply_89 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_134[0][0]']
#
#  global_average_pooling2d_4  (None, 576)                  0         ['multiply_89[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 2)                    1154      ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 940274 (3.59 MB)
# Trainable params: 1154 (4.51 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 250/250 [==============================] - ETA: 0s - loss: 0.3381 - tp: 6923.0000 - fp: 1077.0000 - tn: 6923.0000 - fn: 1077.0000 - precision: 0.8654 - recall: 0.8654 - accuracy: 0.8654 - auc: 0.9487
# Epoch 1: val_loss improved from inf to 0.24593, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 96s 370ms/step - loss: 0.3381 - tp: 6923.0000 - fp: 1077.0000 - tn: 6923.0000 - fn: 1077.0000 - precision: 0.8654 - recall: 0.8654 - accuracy: 0.8654 - auc: 0.9487 - val_loss: 0.2459 - val_tp: 1811.0000 - val_fp: 189.0000 - val_tn: 1811.0000 - val_fn: 189.0000 - val_precision: 0.9055 - val_recall: 0.9055 - val_accuracy: 0.9055 - val_auc: 0.9753 - lr: 0.0010
# Epoch 2/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1443 - tp: 7759.0000 - fp: 241.0000 - tn: 7759.0000 - fn: 241.0000 - precision: 0.9699 - recall: 0.9699 - accuracy: 0.9699 - auc: 0.9952
# Epoch 2: val_loss improved from 0.24593 to 0.16479, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 31s 126ms/step - loss: 0.1443 - tp: 7759.0000 - fp: 241.0000 - tn: 7759.0000 - fn: 241.0000 - precision: 0.9699 - recall: 0.9699 - accuracy: 0.9699 - auc: 0.9952 - val_loss: 0.1648 - val_tp: 1914.0000 - val_fp: 86.0000 - val_tn: 1914.0000 - val_fn: 86.0000 - val_precision: 0.9570 - val_recall: 0.9570 - val_accuracy: 0.9570 - val_auc: 0.9928 - lr: 0.0010
# Epoch 3/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0927 - tp: 7874.0000 - fp: 126.0000 - tn: 7874.0000 - fn: 126.0000 - precision: 0.9843 - recall: 0.9843 - accuracy: 0.9843 - auc: 0.9988
# Epoch 3: val_loss improved from 0.16479 to 0.14560, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 29s 117ms/step - loss: 0.0927 - tp: 7874.0000 - fp: 126.0000 - tn: 7874.0000 - fn: 126.0000 - precision: 0.9843 - recall: 0.9843 - accuracy: 0.9843 - auc: 0.9988 - val_loss: 0.1456 - val_tp: 1894.0000 - val_fp: 106.0000 - val_tn: 1894.0000 - val_fn: 106.0000 - val_precision: 0.9470 - val_recall: 0.9470 - val_accuracy: 0.9470 - val_auc: 0.9917 - lr: 0.0010
# Epoch 4/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0679 - tp: 7922.0000 - fp: 78.0000 - tn: 7922.0000 - fn: 78.0000 - precision: 0.9902 - recall: 0.9902 - accuracy: 0.9902 - auc: 0.9996
# Epoch 4: val_loss improved from 0.14560 to 0.13519, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 31s 123ms/step - loss: 0.0679 - tp: 7922.0000 - fp: 78.0000 - tn: 7922.0000 - fn: 78.0000 - precision: 0.9902 - recall: 0.9902 - accuracy: 0.9902 - auc: 0.9996 - val_loss: 0.1352 - val_tp: 1894.0000 - val_fp: 106.0000 - val_tn: 1894.0000 - val_fn: 106.0000 - val_precision: 0.9470 - val_recall: 0.9470 - val_accuracy: 0.9470 - val_auc: 0.9916 - lr: 0.0010
# Epoch 5/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0524 - tp: 7946.0000 - fp: 54.0000 - tn: 7946.0000 - fn: 54.0000 - precision: 0.9933 - recall: 0.9933 - accuracy: 0.9933 - auc: 0.9998
# Epoch 5: val_loss improved from 0.13519 to 0.12653, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 29s 117ms/step - loss: 0.0524 - tp: 7946.0000 - fp: 54.0000 - tn: 7946.0000 - fn: 54.0000 - precision: 0.9933 - recall: 0.9933 - accuracy: 0.9933 - auc: 0.9998 - val_loss: 0.1265 - val_tp: 1895.0000 - val_fp: 105.0000 - val_tn: 1895.0000 - val_fn: 105.0000 - val_precision: 0.9475 - val_recall: 0.9475 - val_accuracy: 0.9475 - val_auc: 0.9922 - lr: 0.0010
# Epoch 6/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0421 - tp: 7964.0000 - fp: 36.0000 - tn: 7964.0000 - fn: 36.0000 - precision: 0.9955 - recall: 0.9955 - accuracy: 0.9955 - auc: 0.9999
# Epoch 6: val_loss improved from 0.12653 to 0.11930, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 30s 120ms/step - loss: 0.0421 - tp: 7964.0000 - fp: 36.0000 - tn: 7964.0000 - fn: 36.0000 - precision: 0.9955 - recall: 0.9955 - accuracy: 0.9955 - auc: 0.9999 - val_loss: 0.1193 - val_tp: 1898.0000 - val_fp: 102.0000 - val_tn: 1898.0000 - val_fn: 102.0000 - val_precision: 0.9490 - val_recall: 0.9490 - val_accuracy: 0.9490 - val_auc: 0.9930 - lr: 0.0010
# Epoch 7/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0347 - tp: 7978.0000 - fp: 22.0000 - tn: 7978.0000 - fn: 22.0000 - precision: 0.9973 - recall: 0.9973 - accuracy: 0.9973 - auc: 1.0000
# Epoch 7: val_loss did not improve from 0.11930
# 250/250 [==============================] - 28s 113ms/step - loss: 0.0347 - tp: 7978.0000 - fp: 22.0000 - tn: 7978.0000 - fn: 22.0000 - precision: 0.9973 - recall: 0.9973 - accuracy: 0.9973 - auc: 1.0000 - val_loss: 0.1357 - val_tp: 1879.0000 - val_fp: 121.0000 - val_tn: 1879.0000 - val_fn: 121.0000 - val_precision: 0.9395 - val_recall: 0.9395 - val_accuracy: 0.9395 - val_auc: 0.9896 - lr: 0.0010
# Epoch 8/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0297 - tp: 7983.0000 - fp: 17.0000 - tn: 7983.0000 - fn: 17.0000 - precision: 0.9979 - recall: 0.9979 - accuracy: 0.9979 - auc: 1.0000
# Epoch 8: val_loss improved from 0.11930 to 0.11591, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 30s 119ms/step - loss: 0.0297 - tp: 7983.0000 - fp: 17.0000 - tn: 7983.0000 - fn: 17.0000 - precision: 0.9979 - recall: 0.9979 - accuracy: 0.9979 - auc: 1.0000 - val_loss: 0.1159 - val_tp: 1890.0000 - val_fp: 110.0000 - val_tn: 1890.0000 - val_fn: 110.0000 - val_precision: 0.9450 - val_recall: 0.9450 - val_accuracy: 0.9450 - val_auc: 0.9926 - lr: 0.0010
# Epoch 9/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0253 - tp: 7989.0000 - fp: 11.0000 - tn: 7989.0000 - fn: 11.0000 - precision: 0.9986 - recall: 0.9986 - accuracy: 0.9986 - auc: 1.0000
# Epoch 9: val_loss improved from 0.11591 to 0.10955, saving model to Kidney Cancer MobileNet.keras
# 250/250 [==============================] - 29s 115ms/step - loss: 0.0253 - tp: 7989.0000 - fp: 11.0000 - tn: 7989.0000 - fn: 11.0000 - precision: 0.9986 - recall: 0.9986 - accuracy: 0.9986 - auc: 1.0000 - val_loss: 0.1095 - val_tp: 1905.0000 - val_fp: 95.0000 - val_tn: 1905.0000 - val_fn: 95.0000 - val_precision: 0.9525 - val_recall: 0.9525 - val_accuracy: 0.9525 - val_auc: 0.9933 - lr: 0.0010
# Epoch 10/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0217 - tp: 7990.0000 - fp: 10.0000 - tn: 7990.0000 - fn: 10.0000 - precision: 0.9987 - recall: 0.9987 - accuracy: 0.9987 - auc: 1.0000
# Epoch 10: val_loss did not improve from 0.10955
# 250/250 [==============================] - 30s 119ms/step - loss: 0.0217 - tp: 7990.0000 - fp: 10.0000 - tn: 7990.0000 - fn: 10.0000 - precision: 0.9987 - recall: 0.9987 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 0.1173 - val_tp: 1885.0000 - val_fp: 115.0000 - val_tn: 1885.0000 - val_fn: 115.0000 - val_precision: 0.9425 - val_recall: 0.9425 - val_accuracy: 0.9425 - val_auc: 0.9921 - lr: 0.0010
# 63/63 [==============================] - 6s 94ms/step - loss: 0.1173 - tp: 1885.0000 - fp: 115.0000 - tn: 1885.0000 - fn: 115.0000 - precision: 0.9425 - recall: 0.9425 - accuracy: 0.9425 - auc: 0.9921
# Accuracy on the Test Set = 94.25 %
# True Positives = 1885.0. True Negatives = 1885.0
# False Positives = 115.0. False Negatives = 115.0
# Precision = 0.9424999952316284
# Recall = 0.9424999952316284
# F1 Score = 94.24999952316284
# ROC AUC = 0.9921355247497559
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# 63/63 [==============================] - 7s 97ms/step
# Predicted :  [0 0 0 ... 1 1 1]
# Best Hyperparameters (learning rate, batch size): [9.95285412e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Breast Cancer '
cpath = os.path.join(mpath, 'Breast Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 8000 images belonging to 2 classes.
#
# For Val :  Found 2000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['breast_benign', 'breast_malignant']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_5 (Rescaling)     (None, 224, 224, 3)          0         ['input_6[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_5[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_135 (  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_160 (ReLU)            (None, 112, 112, 16)         0         ['tf.__operators__.add_135[0][
#                                                                     0]']
#
#  tf.math.multiply_135 (TFOp  (None, 112, 112, 16)         0         ['re_lu_160[0][0]']
#  Lambda)
#
#  multiply_90 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_135[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_90[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_161 (ReLU)            (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_161[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_136 (  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  TFOpLambda)                                                        /Conv_1[0][0]']
#
#  re_lu_162 (ReLU)            (None, 1, 1, 16)             0         ['tf.__operators__.add_136[0][
#                                                                     0]']
#
#  tf.math.multiply_136 (TFOp  (None, 1, 1, 16)             0         ['re_lu_162[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_161[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_136[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_163 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_163[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_164 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_164[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_165 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_165[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_166 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_166[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_137 (  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_167 (ReLU)            (None, 28, 28, 96)           0         ['tf.__operators__.add_137[0][
#                                                                     0]']
#
#  tf.math.multiply_137 (TFOp  (None, 28, 28, 96)           0         ['re_lu_167[0][0]']
#  Lambda)
#
#  multiply_91 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_137[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_91[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_138 (  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_168 (ReLU)            (None, 14, 14, 96)           0         ['tf.__operators__.add_138[0][
#                                                                     0]']
#
#  tf.math.multiply_138 (TFOp  (None, 14, 14, 96)           0         ['re_lu_168[0][0]']
#  Lambda)
#
#  multiply_92 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_138[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_92[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_139 (  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_169 (ReLU)            (None, 1, 1, 96)             0         ['tf.__operators__.add_139[0][
#                                                                     0]']
#
#  tf.math.multiply_139 (TFOp  (None, 1, 1, 96)             0         ['re_lu_169[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_92[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_139[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_140 (  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_170 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_140[0][
#                                                                     0]']
#
#  tf.math.multiply_140 (TFOp  (None, 14, 14, 240)          0         ['re_lu_170[0][0]']
#  Lambda)
#
#  multiply_93 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_140[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_93[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_141 (  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_171 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_141[0][
#                                                                     0]']
#
#  tf.math.multiply_141 (TFOp  (None, 14, 14, 240)          0         ['re_lu_171[0][0]']
#  Lambda)
#
#  multiply_94 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_141[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_94[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_142 (  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_172 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_142[0][
#                                                                     0]']
#
#  tf.math.multiply_142 (TFOp  (None, 1, 1, 240)            0         ['re_lu_172[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_94[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_142[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_143 (  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_173 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_143[0][
#                                                                     0]']
#
#  tf.math.multiply_143 (TFOp  (None, 14, 14, 240)          0         ['re_lu_173[0][0]']
#  Lambda)
#
#  multiply_95 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_143[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_95[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_144 (  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_174 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_144[0][
#                                                                     0]']
#
#  tf.math.multiply_144 (TFOp  (None, 14, 14, 240)          0         ['re_lu_174[0][0]']
#  Lambda)
#
#  multiply_96 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_144[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_96[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_145 (  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_175 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_145[0][
#                                                                     0]']
#
#  tf.math.multiply_145 (TFOp  (None, 1, 1, 240)            0         ['re_lu_175[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_96[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_145[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_146 (  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_176 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_146[0][
#                                                                     0]']
#
#  tf.math.multiply_146 (TFOp  (None, 14, 14, 120)          0         ['re_lu_176[0][0]']
#  Lambda)
#
#  multiply_97 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_146[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_97[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_147 (  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_177 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_147[0][
#                                                                     0]']
#
#  tf.math.multiply_147 (TFOp  (None, 14, 14, 120)          0         ['re_lu_177[0][0]']
#  Lambda)
#
#  multiply_98 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_147[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_98[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_148 (  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_178 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_148[0][
#                                                                     0]']
#
#  tf.math.multiply_148 (TFOp  (None, 1, 1, 120)            0         ['re_lu_178[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_98[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_148[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_149 (  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_179 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_149[0][
#                                                                     0]']
#
#  tf.math.multiply_149 (TFOp  (None, 14, 14, 144)          0         ['re_lu_179[0][0]']
#  Lambda)
#
#  multiply_99 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_149[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_99[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_150 (  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_180 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_150[0][
#                                                                     0]']
#
#  tf.math.multiply_150 (TFOp  (None, 14, 14, 144)          0         ['re_lu_180[0][0]']
#  Lambda)
#
#  multiply_100 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_150[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_100[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
# ...
#                                                                      'tf.math.multiply_158[0][0]']
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_105[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_159 (  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_189 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_159[0][
#                                                                     0]']
#
#  tf.math.multiply_159 (TFOp  (None, 7, 7, 576)            0         ['re_lu_189[0][0]']
#  Lambda)
#
#  multiply_106 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_159[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_106[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_160 (  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_190 (ReLU)            (None, 1, 1, 576)            0         ['tf.__operators__.add_160[0][
#                                                                     0]']
#
#  tf.math.multiply_160 (TFOp  (None, 1, 1, 576)            0         ['re_lu_190[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_106[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_160[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_161 (  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_191 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_161[0][
#                                                                     0]']
#
#  tf.math.multiply_161 (TFOp  (None, 7, 7, 576)            0         ['re_lu_191[0][0]']
#  Lambda)
#
#  multiply_107 (Multiply)     (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_161[0][0]']
#
#  global_average_pooling2d_5  (None, 576)                  0         ['multiply_107[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 2)                    1154      ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 940274 (3.59 MB)
# Trainable params: 1154 (4.51 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1275 - tp: 7672.0000 - fp: 328.0000 - tn: 7672.0000 - fn: 328.0000 - precision: 0.9590 - recall: 0.9590 - accuracy: 0.9590 - auc: 0.9929
# Epoch 1: val_loss improved from inf to 0.08613, saving model to Breast Cancer MobileNet.keras
# 250/250 [==============================] - 161s 627ms/step - loss: 0.1275 - tp: 7672.0000 - fp: 328.0000 - tn: 7672.0000 - fn: 328.0000 - precision: 0.9590 - recall: 0.9590 - accuracy: 0.9590 - auc: 0.9929 - val_loss: 0.0861 - val_tp: 1937.0000 - val_fp: 63.0000 - val_tn: 1937.0000 - val_fn: 63.0000 - val_precision: 0.9685 - val_recall: 0.9685 - val_accuracy: 0.9685 - val_auc: 0.9963 - lr: 0.0010
# Epoch 2/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0455 - tp: 7896.0000 - fp: 104.0000 - tn: 7896.0000 - fn: 104.0000 - precision: 0.9870 - recall: 0.9870 - accuracy: 0.9870 - auc: 0.9988
# Epoch 2: val_loss improved from 0.08613 to 0.06616, saving model to Breast Cancer MobileNet.keras
# 250/250 [==============================] - 71s 284ms/step - loss: 0.0455 - tp: 7896.0000 - fp: 104.0000 - tn: 7896.0000 - fn: 104.0000 - precision: 0.9870 - recall: 0.9870 - accuracy: 0.9870 - auc: 0.9988 - val_loss: 0.0662 - val_tp: 1953.0000 - val_fp: 47.0000 - val_tn: 1953.0000 - val_fn: 47.0000 - val_precision: 0.9765 - val_recall: 0.9765 - val_accuracy: 0.9765 - val_auc: 0.9976 - lr: 0.0010
# Epoch 3/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0342 - tp: 7919.0000 - fp: 81.0000 - tn: 7919.0000 - fn: 81.0000 - precision: 0.9899 - recall: 0.9899 - accuracy: 0.9899 - auc: 0.9993
# Epoch 3: val_loss did not improve from 0.06616
# 250/250 [==============================] - 72s 290ms/step - loss: 0.0342 - tp: 7919.0000 - fp: 81.0000 - tn: 7919.0000 - fn: 81.0000 - precision: 0.9899 - recall: 0.9899 - accuracy: 0.9899 - auc: 0.9993 - val_loss: 0.0720 - val_tp: 1942.0000 - val_fp: 58.0000 - val_tn: 1942.0000 - val_fn: 58.0000 - val_precision: 0.9710 - val_recall: 0.9710 - val_accuracy: 0.9710 - val_auc: 0.9971 - lr: 0.0010
# Epoch 4/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0280 - tp: 7936.0000 - fp: 64.0000 - tn: 7936.0000 - fn: 64.0000 - precision: 0.9920 - recall: 0.9920 - accuracy: 0.9920 - auc: 0.9995
# Epoch 4: val_loss did not improve from 0.06616
# 250/250 [==============================] - 73s 292ms/step - loss: 0.0280 - tp: 7936.0000 - fp: 64.0000 - tn: 7936.0000 - fn: 64.0000 - precision: 0.9920 - recall: 0.9920 - accuracy: 0.9920 - auc: 0.9995 - val_loss: 0.0740 - val_tp: 1942.0000 - val_fp: 58.0000 - val_tn: 1942.0000 - val_fn: 58.0000 - val_precision: 0.9710 - val_recall: 0.9710 - val_accuracy: 0.9710 - val_auc: 0.9968 - lr: 0.0010
# Epoch 5/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0248 - tp: 7942.0000 - fp: 58.0000 - tn: 7942.0000 - fn: 58.0000 - precision: 0.9927 - recall: 0.9927 - accuracy: 0.9927 - auc: 0.9996
# Epoch 5: val_loss improved from 0.06616 to 0.04845, saving model to Breast Cancer MobileNet.keras
# 250/250 [==============================] - 71s 285ms/step - loss: 0.0248 - tp: 7942.0000 - fp: 58.0000 - tn: 7942.0000 - fn: 58.0000 - precision: 0.9927 - recall: 0.9927 - accuracy: 0.9927 - auc: 0.9996 - val_loss: 0.0484 - val_tp: 1968.0000 - val_fp: 32.0000 - val_tn: 1968.0000 - val_fn: 32.0000 - val_precision: 0.9840 - val_recall: 0.9840 - val_accuracy: 0.9840 - val_auc: 0.9982 - lr: 0.0010
# Epoch 6/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0219 - tp: 7950.0000 - fp: 50.0000 - tn: 7950.0000 - fn: 50.0000 - precision: 0.9937 - recall: 0.9937 - accuracy: 0.9937 - auc: 0.9997
# Epoch 6: val_loss did not improve from 0.04845
# 250/250 [==============================] - 69s 277ms/step - loss: 0.0219 - tp: 7950.0000 - fp: 50.0000 - tn: 7950.0000 - fn: 50.0000 - precision: 0.9937 - recall: 0.9937 - accuracy: 0.9937 - auc: 0.9997 - val_loss: 0.0523 - val_tp: 1963.0000 - val_fp: 37.0000 - val_tn: 1963.0000 - val_fn: 37.0000 - val_precision: 0.9815 - val_recall: 0.9815 - val_accuracy: 0.9815 - val_auc: 0.9984 - lr: 0.0010
# Epoch 7/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0198 - tp: 7954.0000 - fp: 46.0000 - tn: 7954.0000 - fn: 46.0000 - precision: 0.9942 - recall: 0.9942 - accuracy: 0.9942 - auc: 0.9998
# Epoch 7: val_loss did not improve from 0.04845
# 250/250 [==============================] - 70s 278ms/step - loss: 0.0198 - tp: 7954.0000 - fp: 46.0000 - tn: 7954.0000 - fn: 46.0000 - precision: 0.9942 - recall: 0.9942 - accuracy: 0.9942 - auc: 0.9998 - val_loss: 0.0523 - val_tp: 1962.0000 - val_fp: 38.0000 - val_tn: 1962.0000 - val_fn: 38.0000 - val_precision: 0.9810 - val_recall: 0.9810 - val_accuracy: 0.9810 - val_auc: 0.9980 - lr: 0.0010
# Epoch 8/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0182 - tp: 7959.0000 - fp: 41.0000 - tn: 7959.0000 - fn: 41.0000 - precision: 0.9949 - recall: 0.9949 - accuracy: 0.9949 - auc: 0.9998
# Epoch 8: val_loss did not improve from 0.04845
# 250/250 [==============================] - 70s 280ms/step - loss: 0.0182 - tp: 7959.0000 - fp: 41.0000 - tn: 7959.0000 - fn: 41.0000 - precision: 0.9949 - recall: 0.9949 - accuracy: 0.9949 - auc: 0.9998 - val_loss: 0.0490 - val_tp: 1967.0000 - val_fp: 33.0000 - val_tn: 1967.0000 - val_fn: 33.0000 - val_precision: 0.9835 - val_recall: 0.9835 - val_accuracy: 0.9835 - val_auc: 0.9982 - lr: 0.0010
# Epoch 9/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0167 - tp: 7962.0000 - fp: 38.0000 - tn: 7962.0000 - fn: 38.0000 - precision: 0.9952 - recall: 0.9952 - accuracy: 0.9952 - auc: 0.9998
# Epoch 9: val_loss improved from 0.04845 to 0.04735, saving model to Breast Cancer MobileNet.keras
# 250/250 [==============================] - 71s 284ms/step - loss: 0.0167 - tp: 7962.0000 - fp: 38.0000 - tn: 7962.0000 - fn: 38.0000 - precision: 0.9952 - recall: 0.9952 - accuracy: 0.9952 - auc: 0.9998 - val_loss: 0.0473 - val_tp: 1967.0000 - val_fp: 33.0000 - val_tn: 1967.0000 - val_fn: 33.0000 - val_precision: 0.9835 - val_recall: 0.9835 - val_accuracy: 0.9835 - val_auc: 0.9983 - lr: 0.0010
# Epoch 10/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0154 - tp: 7969.0000 - fp: 31.0000 - tn: 7969.0000 - fn: 31.0000 - precision: 0.9961 - recall: 0.9961 - accuracy: 0.9961 - auc: 0.9999
# Epoch 10: val_loss improved from 0.04735 to 0.04072, saving model to Breast Cancer MobileNet.keras
# 250/250 [==============================] - 71s 283ms/step - loss: 0.0154 - tp: 7969.0000 - fp: 31.0000 - tn: 7969.0000 - fn: 31.0000 - precision: 0.9961 - recall: 0.9961 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.0407 - val_tp: 1970.0000 - val_fp: 30.0000 - val_tn: 1970.0000 - val_fn: 30.0000 - val_precision: 0.9850 - val_recall: 0.9850 - val_accuracy: 0.9850 - val_auc: 0.9986 - lr: 0.0010
# 63/63 [==============================] - 14s 230ms/step - loss: 0.0407 - tp: 1970.0000 - fp: 30.0000 - tn: 1970.0000 - fn: 30.0000 - precision: 0.9850 - recall: 0.9850 - accuracy: 0.9850 - auc: 0.9986
# Accuracy on the Test Set = 98.50 %
# True Positives = 1970.0. True Negatives = 1970.0
# False Positives = 30.0. False Negatives = 30.0
# Precision = 0.9850000143051147
# Recall = 0.9850000143051147
# F1 Score = 98.50000143051147
# ROC AUC = 0.9985750913619995
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# 63/63 [==============================] - 15s 220ms/step
# Predicted :  [0 0 0 ... 1 1 1]
# Best Hyperparameters (learning rate, batch size): [9.95285259e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Lymphoma '
cpath = os.path.join(mpath, 'Lymphoma')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 12000 images belonging to 3 classes.
#
# For Val :  Found 3000 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['lymph_cll', 'lymph_fl', 'lymph_mcl']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_6 (Rescaling)     (None, 224, 224, 3)          0         ['input_7[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_6[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_162 (  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_192 (ReLU)            (None, 112, 112, 16)         0         ['tf.__operators__.add_162[0][
#                                                                     0]']
#
#  tf.math.multiply_162 (TFOp  (None, 112, 112, 16)         0         ['re_lu_192[0][0]']
#  Lambda)
#
#  multiply_108 (Multiply)     (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_162[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_108[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_193 (ReLU)            (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_193[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_163 (  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  TFOpLambda)                                                        /Conv_1[0][0]']
#
#  re_lu_194 (ReLU)            (None, 1, 1, 16)             0         ['tf.__operators__.add_163[0][
#                                                                     0]']
#
#  tf.math.multiply_163 (TFOp  (None, 1, 1, 16)             0         ['re_lu_194[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_193[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_163[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_195 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_195[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_196 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_196[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_197 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_197[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_198 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_198[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_164 (  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_199 (ReLU)            (None, 28, 28, 96)           0         ['tf.__operators__.add_164[0][
#                                                                     0]']
#
#  tf.math.multiply_164 (TFOp  (None, 28, 28, 96)           0         ['re_lu_199[0][0]']
#  Lambda)
#
#  multiply_109 (Multiply)     (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_164[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_109[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_165 (  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_200 (ReLU)            (None, 14, 14, 96)           0         ['tf.__operators__.add_165[0][
#                                                                     0]']
#
#  tf.math.multiply_165 (TFOp  (None, 14, 14, 96)           0         ['re_lu_200[0][0]']
#  Lambda)
#
#  multiply_110 (Multiply)     (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_165[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_110[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_166 (  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_201 (ReLU)            (None, 1, 1, 96)             0         ['tf.__operators__.add_166[0][
#                                                                     0]']
#
#  tf.math.multiply_166 (TFOp  (None, 1, 1, 96)             0         ['re_lu_201[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_110[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_166[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_167 (  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_202 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_167[0][
#                                                                     0]']
#
#  tf.math.multiply_167 (TFOp  (None, 14, 14, 240)          0         ['re_lu_202[0][0]']
#  Lambda)
#
#  multiply_111 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_167[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_111[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_168 (  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_203 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_168[0][
#                                                                     0]']
#
#  tf.math.multiply_168 (TFOp  (None, 14, 14, 240)          0         ['re_lu_203[0][0]']
#  Lambda)
#
#  multiply_112 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_168[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_112[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_169 (  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_204 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_169[0][
#                                                                     0]']
#
#  tf.math.multiply_169 (TFOp  (None, 1, 1, 240)            0         ['re_lu_204[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_112[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_169[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_170 (  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_205 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_170[0][
#                                                                     0]']
#
#  tf.math.multiply_170 (TFOp  (None, 14, 14, 240)          0         ['re_lu_205[0][0]']
#  Lambda)
#
#  multiply_113 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_170[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_113[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_171 (  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_206 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_171[0][
#                                                                     0]']
#
#  tf.math.multiply_171 (TFOp  (None, 14, 14, 240)          0         ['re_lu_206[0][0]']
#  Lambda)
#
#  multiply_114 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_171[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_114[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_172 (  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_207 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_172[0][
#                                                                     0]']
#
#  tf.math.multiply_172 (TFOp  (None, 1, 1, 240)            0         ['re_lu_207[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_114[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_172[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_173 (  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_208 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_173[0][
#                                                                     0]']
#
#  tf.math.multiply_173 (TFOp  (None, 14, 14, 120)          0         ['re_lu_208[0][0]']
#  Lambda)
#
#  multiply_115 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_173[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_115[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_174 (  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_209 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_174[0][
#                                                                     0]']
#
#  tf.math.multiply_174 (TFOp  (None, 14, 14, 120)          0         ['re_lu_209[0][0]']
#  Lambda)
#
#  multiply_116 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_174[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_116[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_175 (  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_210 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_175[0][
#                                                                     0]']
#
#  tf.math.multiply_175 (TFOp  (None, 1, 1, 120)            0         ['re_lu_210[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_116[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_175[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_176 (  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_211 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_176[0][
#                                                                     0]']
#
#  tf.math.multiply_176 (TFOp  (None, 14, 14, 144)          0         ['re_lu_211[0][0]']
#  Lambda)
#
#  multiply_117 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_176[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_117[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_177 (  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_212 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_177[0][
#                                                                     0]']
#
#  tf.math.multiply_177 (TFOp  (None, 14, 14, 144)          0         ['re_lu_212[0][0]']
#  Lambda)
#
#  multiply_118 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_177[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_118[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
# ...
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_186 (  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_221 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_186[0][
#                                                                     0]']
#
#  tf.math.multiply_186 (TFOp  (None, 7, 7, 576)            0         ['re_lu_221[0][0]']
#  Lambda)
#
#  multiply_124 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_186[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_124[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_187 (  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_222 (ReLU)            (None, 1, 1, 576)            0         ['tf.__operators__.add_187[0][
#                                                                     0]']
#
#  tf.math.multiply_187 (TFOp  (None, 1, 1, 576)            0         ['re_lu_222[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_124[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_187[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_188 (  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_223 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_188[0][
#                                                                     0]']
#
#  tf.math.multiply_188 (TFOp  (None, 7, 7, 576)            0         ['re_lu_223[0][0]']
#  Lambda)
#
#  multiply_125 (Multiply)     (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_188[0][0]']
#
#  global_average_pooling2d_6  (None, 576)                  0         ['multiply_125[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 3)                    1731      ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 940851 (3.59 MB)
# Trainable params: 1731 (6.76 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 375/375 [==============================] - ETA: 0s - loss: 0.8414 - tp: 5109.0000 - fp: 2051.0000 - tn: 21949.0000 - fn: 6891.0000 - precision: 0.7135 - recall: 0.4257 - accuracy: 0.6162 - auc: 0.8040
# Epoch 1: val_loss improved from inf to 0.70351, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 166s 429ms/step - loss: 0.8414 - tp: 5109.0000 - fp: 2051.0000 - tn: 21949.0000 - fn: 6891.0000 - precision: 0.7135 - recall: 0.4257 - accuracy: 0.6162 - auc: 0.8040 - val_loss: 0.7035 - val_tp: 1722.0000 - val_fp: 479.0000 - val_tn: 5521.0000 - val_fn: 1278.0000 - val_precision: 0.7824 - val_recall: 0.5740 - val_accuracy: 0.7150 - val_auc: 0.8779 - lr: 0.0010
# Epoch 2/10
# 375/375 [==============================] - ETA: 0s - loss: 0.6627 - tp: 7458.0000 - fp: 2027.0000 - tn: 21973.0000 - fn: 4542.0000 - precision: 0.7863 - recall: 0.6215 - accuracy: 0.7295 - auc: 0.8889
# Epoch 2: val_loss improved from 0.70351 to 0.62424, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 58s 156ms/step - loss: 0.6627 - tp: 7458.0000 - fp: 2027.0000 - tn: 21973.0000 - fn: 4542.0000 - precision: 0.7863 - recall: 0.6215 - accuracy: 0.7295 - auc: 0.8889 - val_loss: 0.6242 - val_tp: 1997.0000 - val_fp: 494.0000 - val_tn: 5506.0000 - val_fn: 1003.0000 - val_precision: 0.8017 - val_recall: 0.6657 - val_accuracy: 0.7500 - val_auc: 0.9025 - lr: 0.0010
# Epoch 3/10
# 375/375 [==============================] - ETA: 0s - loss: 0.5958 - tp: 8231.0000 - fp: 1936.0000 - tn: 22064.0000 - fn: 3769.0000 - precision: 0.8096 - recall: 0.6859 - accuracy: 0.7644 - auc: 0.9107
# Epoch 3: val_loss improved from 0.62424 to 0.58404, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 58s 155ms/step - loss: 0.5958 - tp: 8231.0000 - fp: 1936.0000 - tn: 22064.0000 - fn: 3769.0000 - precision: 0.8096 - recall: 0.6859 - accuracy: 0.7644 - auc: 0.9107 - val_loss: 0.5840 - val_tp: 2114.0000 - val_fp: 494.0000 - val_tn: 5506.0000 - val_fn: 886.0000 - val_precision: 0.8106 - val_recall: 0.7047 - val_accuracy: 0.7703 - val_auc: 0.9135 - lr: 0.0010
# Epoch 4/10
# 375/375 [==============================] - ETA: 0s - loss: 0.5522 - tp: 8672.0000 - fp: 1850.0000 - tn: 22150.0000 - fn: 3328.0000 - precision: 0.8242 - recall: 0.7227 - accuracy: 0.7842 - auc: 0.9243
# Epoch 4: val_loss improved from 0.58404 to 0.54518, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 59s 157ms/step - loss: 0.5522 - tp: 8672.0000 - fp: 1850.0000 - tn: 22150.0000 - fn: 3328.0000 - precision: 0.8242 - recall: 0.7227 - accuracy: 0.7842 - auc: 0.9243 - val_loss: 0.5452 - val_tp: 2180.0000 - val_fp: 453.0000 - val_tn: 5547.0000 - val_fn: 820.0000 - val_precision: 0.8280 - val_recall: 0.7267 - val_accuracy: 0.7897 - val_auc: 0.9255 - lr: 0.0010
# Epoch 5/10
# 375/375 [==============================] - ETA: 0s - loss: 0.5220 - tp: 8958.0000 - fp: 1772.0000 - tn: 22228.0000 - fn: 3042.0000 - precision: 0.8349 - recall: 0.7465 - accuracy: 0.8033 - auc: 0.9322
# Epoch 5: val_loss improved from 0.54518 to 0.52105, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 58s 156ms/step - loss: 0.5220 - tp: 8958.0000 - fp: 1772.0000 - tn: 22228.0000 - fn: 3042.0000 - precision: 0.8349 - recall: 0.7465 - accuracy: 0.8033 - auc: 0.9322 - val_loss: 0.5211 - val_tp: 2238.0000 - val_fp: 470.0000 - val_tn: 5530.0000 - val_fn: 762.0000 - val_precision: 0.8264 - val_recall: 0.7460 - val_accuracy: 0.7963 - val_auc: 0.9318 - lr: 0.0010
# Epoch 6/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4984 - tp: 9144.0000 - fp: 1690.0000 - tn: 22310.0000 - fn: 2856.0000 - precision: 0.8440 - recall: 0.7620 - accuracy: 0.8117 - auc: 0.9383
# Epoch 6: val_loss improved from 0.52105 to 0.49528, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 57s 153ms/step - loss: 0.4984 - tp: 9144.0000 - fp: 1690.0000 - tn: 22310.0000 - fn: 2856.0000 - precision: 0.8440 - recall: 0.7620 - accuracy: 0.8117 - auc: 0.9383 - val_loss: 0.4953 - val_tp: 2296.0000 - val_fp: 428.0000 - val_tn: 5572.0000 - val_fn: 704.0000 - val_precision: 0.8429 - val_recall: 0.7653 - val_accuracy: 0.8123 - val_auc: 0.9387 - lr: 0.0010
# Epoch 7/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4778 - tp: 9291.0000 - fp: 1665.0000 - tn: 22335.0000 - fn: 2709.0000 - precision: 0.8480 - recall: 0.7742 - accuracy: 0.8190 - auc: 0.9434
# Epoch 7: val_loss improved from 0.49528 to 0.48392, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 59s 156ms/step - loss: 0.4778 - tp: 9291.0000 - fp: 1665.0000 - tn: 22335.0000 - fn: 2709.0000 - precision: 0.8480 - recall: 0.7742 - accuracy: 0.8190 - auc: 0.9434 - val_loss: 0.4839 - val_tp: 2318.0000 - val_fp: 434.0000 - val_tn: 5566.0000 - val_fn: 682.0000 - val_precision: 0.8423 - val_recall: 0.7727 - val_accuracy: 0.8153 - val_auc: 0.9409 - lr: 0.0010
# Epoch 8/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4629 - tp: 9404.0000 - fp: 1619.0000 - tn: 22381.0000 - fn: 2596.0000 - precision: 0.8531 - recall: 0.7837 - accuracy: 0.8241 - auc: 0.9468
# Epoch 8: val_loss improved from 0.48392 to 0.46618, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 60s 160ms/step - loss: 0.4629 - tp: 9404.0000 - fp: 1619.0000 - tn: 22381.0000 - fn: 2596.0000 - precision: 0.8531 - recall: 0.7837 - accuracy: 0.8241 - auc: 0.9468 - val_loss: 0.4662 - val_tp: 2342.0000 - val_fp: 417.0000 - val_tn: 5583.0000 - val_fn: 658.0000 - val_precision: 0.8489 - val_recall: 0.7807 - val_accuracy: 0.8227 - val_auc: 0.9452 - lr: 0.0010
# Epoch 9/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4521 - tp: 9495.0000 - fp: 1601.0000 - tn: 22399.0000 - fn: 2505.0000 - precision: 0.8557 - recall: 0.7912 - accuracy: 0.8297 - auc: 0.9486
# Epoch 9: val_loss improved from 0.46618 to 0.46211, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 58s 155ms/step - loss: 0.4521 - tp: 9495.0000 - fp: 1601.0000 - tn: 22399.0000 - fn: 2505.0000 - precision: 0.8557 - recall: 0.7912 - accuracy: 0.8297 - auc: 0.9486 - val_loss: 0.4621 - val_tp: 2346.0000 - val_fp: 418.0000 - val_tn: 5582.0000 - val_fn: 654.0000 - val_precision: 0.8488 - val_recall: 0.7820 - val_accuracy: 0.8227 - val_auc: 0.9448 - lr: 0.0010
# Epoch 10/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4391 - tp: 9590.0000 - fp: 1571.0000 - tn: 22429.0000 - fn: 2410.0000 - precision: 0.8592 - recall: 0.7992 - accuracy: 0.8325 - auc: 0.9515
# Epoch 10: val_loss improved from 0.46211 to 0.44693, saving model to Lymphoma MobileNet.keras
# 375/375 [==============================] - 60s 159ms/step - loss: 0.4391 - tp: 9590.0000 - fp: 1571.0000 - tn: 22429.0000 - fn: 2410.0000 - precision: 0.8592 - recall: 0.7992 - accuracy: 0.8325 - auc: 0.9515 - val_loss: 0.4469 - val_tp: 2389.0000 - val_fp: 405.0000 - val_tn: 5595.0000 - val_fn: 611.0000 - val_precision: 0.8550 - val_recall: 0.7963 - val_accuracy: 0.8290 - val_auc: 0.9491 - lr: 0.0010
# 94/94 [==============================] - 12s 125ms/step - loss: 0.4469 - tp: 2389.0000 - fp: 405.0000 - tn: 5595.0000 - fn: 611.0000 - precision: 0.8550 - recall: 0.7963 - accuracy: 0.8290 - auc: 0.9491
# Accuracy on the Test Set = 82.90 %
# True Positives = 2389.0. True Negatives = 5595.0
# False Positives = 405.0. False Negatives = 611.0
# Precision = 0.8550465106964111
# Recall = 0.7963333129882812
# F1 Score = 82.4646166625264
# ROC AUC = 0.9490994215011597
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 94/94 [==============================] - 13s 127ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# Best Hyperparameters (learning rate, batch size): [9.95284692e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')

# %%
className = 'Brain Cancer '
cpath = os.path.join(mpath, 'Brain Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel1(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 12000 images belonging to 3 classes.
#
# For Val :  Found 3000 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['brain_glioma', 'brain_menin', 'brain_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_7 (Rescaling)     (None, 224, 224, 3)          0         ['input_8[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_7[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_189 (  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_224 (ReLU)            (None, 112, 112, 16)         0         ['tf.__operators__.add_189[0][
#                                                                     0]']
#
#  tf.math.multiply_189 (TFOp  (None, 112, 112, 16)         0         ['re_lu_224[0][0]']
#  Lambda)
#
#  multiply_126 (Multiply)     (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_189[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_126[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_225 (ReLU)            (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_225[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.__operators__.add_190 (  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  TFOpLambda)                                                        /Conv_1[0][0]']
#
#  re_lu_226 (ReLU)            (None, 1, 1, 16)             0         ['tf.__operators__.add_190[0][
#                                                                     0]']
#
#  tf.math.multiply_190 (TFOp  (None, 1, 1, 16)             0         ['re_lu_226[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_225[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_190[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_227 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_227[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_228 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_228[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_229 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_229[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_230 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_230[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_191 (  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_231 (ReLU)            (None, 28, 28, 96)           0         ['tf.__operators__.add_191[0][
#                                                                     0]']
#
#  tf.math.multiply_191 (TFOp  (None, 28, 28, 96)           0         ['re_lu_231[0][0]']
#  Lambda)
#
#  multiply_127 (Multiply)     (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_191[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_127[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_192 (  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_232 (ReLU)            (None, 14, 14, 96)           0         ['tf.__operators__.add_192[0][
#                                                                     0]']
#
#  tf.math.multiply_192 (TFOp  (None, 14, 14, 96)           0         ['re_lu_232[0][0]']
#  Lambda)
#
#  multiply_128 (Multiply)     (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_192[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_128[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_193 (  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_233 (ReLU)            (None, 1, 1, 96)             0         ['tf.__operators__.add_193[0][
#                                                                     0]']
#
#  tf.math.multiply_193 (TFOp  (None, 1, 1, 96)             0         ['re_lu_233[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_128[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_193[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_194 (  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_234 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_194[0][
#                                                                     0]']
#
#  tf.math.multiply_194 (TFOp  (None, 14, 14, 240)          0         ['re_lu_234[0][0]']
#  Lambda)
#
#  multiply_129 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_194[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_129[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_195 (  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_235 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_195[0][
#                                                                     0]']
#
#  tf.math.multiply_195 (TFOp  (None, 14, 14, 240)          0         ['re_lu_235[0][0]']
#  Lambda)
#
#  multiply_130 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_195[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_130[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_196 (  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_236 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_196[0][
#                                                                     0]']
#
#  tf.math.multiply_196 (TFOp  (None, 1, 1, 240)            0         ['re_lu_236[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_130[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_196[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_197 (  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_237 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_197[0][
#                                                                     0]']
#
#  tf.math.multiply_197 (TFOp  (None, 14, 14, 240)          0         ['re_lu_237[0][0]']
#  Lambda)
#
#  multiply_131 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_197[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_131[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_198 (  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_238 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_198[0][
#                                                                     0]']
#
#  tf.math.multiply_198 (TFOp  (None, 14, 14, 240)          0         ['re_lu_238[0][0]']
#  Lambda)
#
#  multiply_132 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_198[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_132[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_199 (  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_239 (ReLU)            (None, 1, 1, 240)            0         ['tf.__operators__.add_199[0][
#                                                                     0]']
#
#  tf.math.multiply_199 (TFOp  (None, 1, 1, 240)            0         ['re_lu_239[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_132[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_199[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_200 (  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_240 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_200[0][
#                                                                     0]']
#
#  tf.math.multiply_200 (TFOp  (None, 14, 14, 120)          0         ['re_lu_240[0][0]']
#  Lambda)
#
#  multiply_133 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_200[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_133[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_201 (  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_241 (ReLU)            (None, 14, 14, 120)          0         ['tf.__operators__.add_201[0][
#                                                                     0]']
#
#  tf.math.multiply_201 (TFOp  (None, 14, 14, 120)          0         ['re_lu_241[0][0]']
#  Lambda)
#
#  multiply_134 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_201[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_134[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_202 (  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_242 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_202[0][
#                                                                     0]']
#
#  tf.math.multiply_202 (TFOp  (None, 1, 1, 120)            0         ['re_lu_242[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_134[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_202[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_203 (  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_243 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_203[0][
#                                                                     0]']
#
#  tf.math.multiply_203 (TFOp  (None, 14, 14, 144)          0         ['re_lu_243[0][0]']
#  Lambda)
#
#  multiply_135 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_203[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_135[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_204 (  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_244 (ReLU)            (None, 14, 14, 144)          0         ['tf.__operators__.add_204[0][
#                                                                     0]']
#
#  tf.math.multiply_204 (TFOp  (None, 14, 14, 144)          0         ['re_lu_244[0][0]']
#  Lambda)
#
#  multiply_136 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_204[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_136[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
# ...
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_213 (  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_253 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_213[0][
#                                                                     0]']
#
#  tf.math.multiply_213 (TFOp  (None, 7, 7, 576)            0         ['re_lu_253[0][0]']
#  Lambda)
#
#  multiply_142 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_213[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_142[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_214 (  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_254 (ReLU)            (None, 1, 1, 576)            0         ['tf.__operators__.add_214[0][
#                                                                     0]']
#
#  tf.math.multiply_214 (TFOp  (None, 1, 1, 576)            0         ['re_lu_254[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_142[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_214[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_215 (  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_255 (ReLU)            (None, 7, 7, 576)            0         ['tf.__operators__.add_215[0][
#                                                                     0]']
#
#  tf.math.multiply_215 (TFOp  (None, 7, 7, 576)            0         ['re_lu_255[0][0]']
#  Lambda)
#
#  multiply_143 (Multiply)     (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_215[0][0]']
#
#  global_average_pooling2d_7  (None, 576)                  0         ['multiply_143[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 3)                    1731      ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 940851 (3.59 MB)
# Trainable params: 1731 (6.76 KB)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 375/375 [==============================] - ETA: 0s - loss: 0.4332 - tp: 9412.0000 - fp: 1167.0000 - tn: 22833.0000 - fn: 2588.0000 - precision: 0.8897 - recall: 0.7843 - accuracy: 0.8441 - auc: 0.9588
# Epoch 1: val_loss improved from inf to 0.27054, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 142s 368ms/step - loss: 0.4332 - tp: 9412.0000 - fp: 1167.0000 - tn: 22833.0000 - fn: 2588.0000 - precision: 0.8897 - recall: 0.7843 - accuracy: 0.8441 - auc: 0.9588 - val_loss: 0.2705 - val_tp: 2679.0000 - val_fp: 237.0000 - val_tn: 5763.0000 - val_fn: 321.0000 - val_precision: 0.9187 - val_recall: 0.8930 - val_accuracy: 0.9083 - val_auc: 0.9829 - lr: 0.0010
# Epoch 2/10
# 375/375 [==============================] - ETA: 0s - loss: 0.2316 - tp: 10987.0000 - fp: 774.0000 - tn: 23226.0000 - fn: 1013.0000 - precision: 0.9342 - recall: 0.9156 - accuracy: 0.9258 - auc: 0.9868
# Epoch 2: val_loss improved from 0.27054 to 0.21729, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 41s 110ms/step - loss: 0.2316 - tp: 10987.0000 - fp: 774.0000 - tn: 23226.0000 - fn: 1013.0000 - precision: 0.9342 - recall: 0.9156 - accuracy: 0.9258 - auc: 0.9868 - val_loss: 0.2173 - val_tp: 2755.0000 - val_fp: 201.0000 - val_tn: 5799.0000 - val_fn: 245.0000 - val_precision: 0.9320 - val_recall: 0.9183 - val_accuracy: 0.9270 - val_auc: 0.9874 - lr: 0.0010
# Epoch 3/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1891 - tp: 11193.0000 - fp: 644.0000 - tn: 23356.0000 - fn: 807.0000 - precision: 0.9456 - recall: 0.9327 - accuracy: 0.9400 - auc: 0.9909
# Epoch 3: val_loss improved from 0.21729 to 0.18219, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 43s 114ms/step - loss: 0.1891 - tp: 11193.0000 - fp: 644.0000 - tn: 23356.0000 - fn: 807.0000 - precision: 0.9456 - recall: 0.9327 - accuracy: 0.9400 - auc: 0.9909 - val_loss: 0.1822 - val_tp: 2801.0000 - val_fp: 171.0000 - val_tn: 5829.0000 - val_fn: 199.0000 - val_precision: 0.9425 - val_recall: 0.9337 - val_accuracy: 0.9400 - val_auc: 0.9913 - lr: 0.0010
# Epoch 4/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1656 - tp: 11325.0000 - fp: 575.0000 - tn: 23425.0000 - fn: 675.0000 - precision: 0.9517 - recall: 0.9438 - accuracy: 0.9480 - auc: 0.9927
# Epoch 4: val_loss improved from 0.18219 to 0.16851, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 42s 112ms/step - loss: 0.1656 - tp: 11325.0000 - fp: 575.0000 - tn: 23425.0000 - fn: 675.0000 - precision: 0.9517 - recall: 0.9438 - accuracy: 0.9480 - auc: 0.9927 - val_loss: 0.1685 - val_tp: 2822.0000 - val_fp: 155.0000 - val_tn: 5845.0000 - val_fn: 178.0000 - val_precision: 0.9479 - val_recall: 0.9407 - val_accuracy: 0.9473 - val_auc: 0.9923 - lr: 0.0010
# Epoch 5/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1499 - tp: 11388.0000 - fp: 523.0000 - tn: 23477.0000 - fn: 612.0000 - precision: 0.9561 - recall: 0.9490 - accuracy: 0.9525 - auc: 0.9941
# Epoch 5: val_loss improved from 0.16851 to 0.15038, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 42s 113ms/step - loss: 0.1499 - tp: 11388.0000 - fp: 523.0000 - tn: 23477.0000 - fn: 612.0000 - precision: 0.9561 - recall: 0.9490 - accuracy: 0.9525 - auc: 0.9941 - val_loss: 0.1504 - val_tp: 2840.0000 - val_fp: 141.0000 - val_tn: 5859.0000 - val_fn: 160.0000 - val_precision: 0.9527 - val_recall: 0.9467 - val_accuracy: 0.9503 - val_auc: 0.9940 - lr: 0.0010
# Epoch 6/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1371 - tp: 11441.0000 - fp: 487.0000 - tn: 23513.0000 - fn: 559.0000 - precision: 0.9592 - recall: 0.9534 - accuracy: 0.9566 - auc: 0.9949
# Epoch 6: val_loss improved from 0.15038 to 0.14161, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 43s 115ms/step - loss: 0.1371 - tp: 11441.0000 - fp: 487.0000 - tn: 23513.0000 - fn: 559.0000 - precision: 0.9592 - recall: 0.9534 - accuracy: 0.9566 - auc: 0.9949 - val_loss: 0.1416 - val_tp: 2847.0000 - val_fp: 139.0000 - val_tn: 5861.0000 - val_fn: 153.0000 - val_precision: 0.9534 - val_recall: 0.9490 - val_accuracy: 0.9523 - val_auc: 0.9946 - lr: 0.0010
# Epoch 7/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1272 - tp: 11483.0000 - fp: 461.0000 - tn: 23539.0000 - fn: 517.0000 - precision: 0.9614 - recall: 0.9569 - accuracy: 0.9596 - auc: 0.9957
# Epoch 7: val_loss improved from 0.14161 to 0.13420, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 43s 114ms/step - loss: 0.1272 - tp: 11483.0000 - fp: 461.0000 - tn: 23539.0000 - fn: 517.0000 - precision: 0.9614 - recall: 0.9569 - accuracy: 0.9596 - auc: 0.9957 - val_loss: 0.1342 - val_tp: 2853.0000 - val_fp: 134.0000 - val_tn: 5866.0000 - val_fn: 147.0000 - val_precision: 0.9551 - val_recall: 0.9510 - val_accuracy: 0.9533 - val_auc: 0.9952 - lr: 0.0010
# Epoch 8/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1198 - tp: 11516.0000 - fp: 434.0000 - tn: 23566.0000 - fn: 484.0000 - precision: 0.9637 - recall: 0.9597 - accuracy: 0.9620 - auc: 0.9962
# Epoch 8: val_loss improved from 0.13420 to 0.12652, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 43s 115ms/step - loss: 0.1198 - tp: 11516.0000 - fp: 434.0000 - tn: 23566.0000 - fn: 484.0000 - precision: 0.9637 - recall: 0.9597 - accuracy: 0.9620 - auc: 0.9962 - val_loss: 0.1265 - val_tp: 2868.0000 - val_fp: 124.0000 - val_tn: 5876.0000 - val_fn: 132.0000 - val_precision: 0.9586 - val_recall: 0.9560 - val_accuracy: 0.9570 - val_auc: 0.9956 - lr: 0.0010
# Epoch 9/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1125 - tp: 11557.0000 - fp: 409.0000 - tn: 23591.0000 - fn: 443.0000 - precision: 0.9658 - recall: 0.9631 - accuracy: 0.9648 - auc: 0.9967
# Epoch 9: val_loss improved from 0.12652 to 0.12288, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 41s 110ms/step - loss: 0.1125 - tp: 11557.0000 - fp: 409.0000 - tn: 23591.0000 - fn: 443.0000 - precision: 0.9658 - recall: 0.9631 - accuracy: 0.9648 - auc: 0.9967 - val_loss: 0.1229 - val_tp: 2864.0000 - val_fp: 123.0000 - val_tn: 5877.0000 - val_fn: 136.0000 - val_precision: 0.9588 - val_recall: 0.9547 - val_accuracy: 0.9563 - val_auc: 0.9959 - lr: 0.0010
# Epoch 10/10
# 375/375 [==============================] - ETA: 0s - loss: 0.1078 - tp: 11571.0000 - fp: 389.0000 - tn: 23611.0000 - fn: 429.0000 - precision: 0.9675 - recall: 0.9643 - accuracy: 0.9661 - auc: 0.9970
# Epoch 10: val_loss improved from 0.12288 to 0.11502, saving model to Brain Cancer MobileNet.keras
# 375/375 [==============================] - 43s 115ms/step - loss: 0.1078 - tp: 11571.0000 - fp: 389.0000 - tn: 23611.0000 - fn: 429.0000 - precision: 0.9675 - recall: 0.9643 - accuracy: 0.9661 - auc: 0.9970 - val_loss: 0.1150 - val_tp: 2882.0000 - val_fp: 108.0000 - val_tn: 5892.0000 - val_fn: 118.0000 - val_precision: 0.9639 - val_recall: 0.9607 - val_accuracy: 0.9620 - val_auc: 0.9964 - lr: 0.0010
# 94/94 [==============================] - 8s 86ms/step - loss: 0.1150 - tp: 2882.0000 - fp: 108.0000 - tn: 5892.0000 - fn: 118.0000 - precision: 0.9639 - recall: 0.9607 - accuracy: 0.9620 - auc: 0.9964
# Accuracy on the Test Set = 96.20 %
# True Positives = 2882.0. True Negatives = 5892.0
# False Positives = 108.0. False Negatives = 118.0
# Precision = 0.9638795852661133
# Recall = 0.9606666564941406
# F1 Score = 96.22704389722908
# ROC AUC = 0.9964373111724854
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 94/94 [==============================] - 9s 84ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# Best Hyperparameters (learning rate, batch size): [9.95284587e-03 2.55999963e+02]
# /tmp/ipykernel_34/1764077853.py:22: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective_function, x0=np.random.rand(2), bounds=search_space, method='Powell')
